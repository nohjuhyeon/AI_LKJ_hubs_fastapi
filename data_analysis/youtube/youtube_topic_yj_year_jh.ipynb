# %%
# 한글 폰트 설치
# !apt-get install -y fonts-nanum
# !fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 설치 후 colab 경우 Reuntime > Restart session 필요
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# Font directories:
# 	/root/.local/share/fonts
# 	/usr/local/share/fonts
# 	/usr/share/fonts
# 	/root/.fonts
# 	/usr/share/fonts/truetype
# 	/usr/share/fonts/truetype/dejavu
# 	/usr/share/fonts/truetype/liberation
# 	/usr/share/fonts/truetype/nanum
# /root/.local/share/fonts: skipping, no such directory
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/dejavu: caching, new cache contents: 22 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/dejavu: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rc('font', family='NanumBarunGothic') # 혹은 다른 설치한 Nanum 폰트 사용

# %% [markdown]
# ## data

# %%
import pandas as pd
import numpy as np

# %%
df_youtube_comments = pd.read_csv("youtube_comments_concat.csv")

# %%
df_youtube_comments = df_youtube_comments.dropna()

# %% [markdown]
# ## 년도별/계절별 댓글 topic 분류

# %% [markdown]
# ### year

# %%
df_youtube_comments['date_year'].value_counts() # 2019 ~ 2024
# Out:
# date_year
# 2021    7732
# 2022    7009
# 2020    6413
# 2023    5794
# 2019    3158
# 2024    1216
# Name: count, dtype: int64

# %%
df_youtube_comments
# Out:
#                             _id  \
# 0      6631d19b119b5f09bb9288e4
# 1      6631d19b119b5f09bb9288e5
# 2      6631d19b119b5f09bb9288e6
# 3      6631d19c119b5f09bb9288e7
# 4      6631d19c119b5f09bb9288e8
# ...                         ...
# 34451  6631cc977547545ba205e82c
# 34452  6631cc977547545ba205e82d
# 34453  6631cc977547545ba205e82e
# 34454  6631cc977547545ba205e82f
# 34455  6631cc977547545ba205e830
#
#                                                 title        date  \
# 0      🇰🇷 459일 만에 한국에 왔는데, 골방 신세로 보낸 2주일😷 [자가격리 vlog]  2020-04-11
# 1      🇰🇷 459일 만에 한국에 왔는데, 골방 신세로 보낸 2주일😷 [자가격리 vlog]  2020-04-11
# 2      🇰🇷 459일 만에 한국에 왔는데, 골방 신세로 보낸 2주일😷 [자가격리 vlog]  2020-04-11
# 3      🇰🇷 459일 만에 한국에 왔는데, 골방 신세로 보낸 2주일😷 [자가격리 vlog]  2020-04-11
# 4      🇰🇷 459일 만에 한국에 왔는데, 골방 신세로 보낸 2주일😷 [자가격리 vlog]  2020-04-11
# ...                                               ...         ...
# 34451  국내여행지 가을 영월 가볼만한곳 BEST 4 붉은 메밀 꽃이 피었습니다 강원도 여행  2021-10-09
# 34452  국내여행지 가을 영월 가볼만한곳 BEST 4 붉은 메밀 꽃이 피었습니다 강원도 여행  2021-10-09
# 34453  국내여행지 가을 영월 가볼만한곳 BEST 4 붉은 메밀 꽃이 피었습니다 강원도 여행  2021-10-09
# 34454  국내여행지 가을 영월 가볼만한곳 BEST 4 붉은 메밀 꽃이 피었습니다 강원도 여행  2021-10-09
# 34455  국내여행지 가을 영월 가볼만한곳 BEST 4 붉은 메밀 꽃이 피었습니다 강원도 여행  2021-10-09
#
#                 views recommend  \
# 0      조회수 2,696,715회      2.8만
# 1      조회수 2,696,715회      2.8만
# 2      조회수 2,696,715회      2.8만
# 3      조회수 2,696,715회      2.8만
# 4      조회수 2,696,715회      2.8만
# ...               ...       ...
# 34451     조회수 18,336회       285
# 34452     조회수 18,336회       285
# 34453     조회수 18,336회       285
# 34454     조회수 18,336회       285
# 34455     조회수 18,336회       285
#
#                                                 contents  \
# 0      #자가격리브이로그 #여행가jay\n---------------------------...
# 1      #자가격리브이로그 #여행가jay\n---------------------------...
# 2      #자가격리브이로그 #여행가jay\n---------------------------...
# 3      #자가격리브이로그 #여행가jay\n---------------------------...
# 4      #자가격리브이로그 #여행가jay\n---------------------------...
# ...                                                  ...
# 34451  국내여행지 가을 영월 가볼만한곳 BEST 4 붉은 메밀 꽃이 피었습니다  강원도 여...
# 34452  국내여행지 가을 영월 가볼만한곳 BEST 4 붉은 메밀 꽃이 피었습니다  강원도 여...
# 34453  국내여행지 가을 영월 가볼만한곳 BEST 4 붉은 메밀 꽃이 피었습니다  강원도 여...
# 34454  국내여행지 가을 영월 가볼만한곳 BEST 4 붉은 메밀 꽃이 피었습니다  강원도 여...
# 34455  국내여행지 가을 영월 가볼만한곳 BEST 4 붉은 메밀 꽃이 피었습니다  강원도 여...
#
#                                                    reply  date_year  \
# 0      +해당 영상에 대한 수익금의 일부를 대한민국 의료진에게 기부하였습니다.\n\n점점 ...       2020
# 1      가족이라 껴안고도싶고 하겠지만 메뉴얼대로 공항에서부터 철저하게 격리절차 밟는과정은 ...       2020
# 2      평소에 조카한테 얼마나 잘해줫으면 저렇게  삼촌을 좋아하냐 ㅎㅎ 참 좋은사람이라는게...       2020
# 3      와 눈물나... 2:20 나를 누구보다 아끼고 잘되길 바라는 우리의 부모님들.. 아...       2020
# 4      부모님이 세계여행 응원해주시고 믿어주신거 대단하시네요. 플랜카드까지 달아놓아주신거랑...       2020
# ...                                                  ...        ...
# 34451  붉은 메일이 있다는건 첨 알았네요. 해외 여행하시는 분들 국내는 다 가보고 해외여행...       2021
# 34452  영월에 선돌.한반도지형은\n가봤는데 붉은메밀꽃밭\n가보려는데 카카오네비에\n주소 쳐...       2021
# 34453      영월 ...강추 여행지!!!!!!\n감히 한마디 하자면 ㅋㅋㅋㅋ \n청령포 추가요       2021
# 34454                    붉은 메밀은 어디가야 볼 수 있을까요? 주소가 궁금합니다       2021
# 34455                                      메일로 연락이 어렵습니다       2021
#
#        date_month           title_noun  dominant_topic_number  \
# 0               4           골방 신세 자 격리                      2
# 1               4           골방 신세 자 격리                      2
# 2               4           골방 신세 자 격리                      2
# 3               4           골방 신세 자 격리                      2
# 4               4           골방 신세 자 격리                      2
# ...           ...                  ...                    ...
# 34451          10    가을 영월 곳 메밀 꽃 강원도                       1
# 34452          10    가을 영월 곳 메밀 꽃 강원도                       1
# 34453          10    가을 영월 곳 메밀 꽃 강원도                       1
# 34454          10    가을 영월 곳 메밀 꽃 강원도                       1
# 34455          10    가을 영월 곳 메밀 꽃 강원도                       1
#
#                                        reply_clean_mecab  \
# 0      해당  수익금 일부 민국 의료진 기부 상황 사태 조심 모두 격리 사회 거리 두기 신...
# 1                       가족 메뉴 공항 철저 격리 절차 과정 시국 모습 부모 존경
# 2                                            평소 조카 삼촌 사람
# 3                                    눈물 부모 아들 방 플랜 카드 생각
# 4                            부모 세계  응원 플랜 카드 격리 창고 정리 센스
# ...                                                  ...
# 34451                             메일 해외  국내 해외 방식  국내  때
# 34452      영월 선돌 한반도 지형 메밀꽃 밭 카카오 네비 주소 영월군 목골 마을 네비 주소
# 34453                                  영월 강추  한마디 청령포 추가
# 34454                                              메밀 주소
# 34455                                              메일 연락
#
#                                          reply_clean_okt  \
# 0      해당 영상 대한 수익금 일부 대한민국 의료 진 기부 점점  상황  사태 대한 조심성...
# 1             가족 메뉴얼 공항 철 격리 절차 과정 정말  시국 모습  부모님 존경 스럽다
# 2                         평소 조카 얼마나 잘 줫으 삼촌 좋 좋다 사람 게 화팅
# 3                     누구 잘 우리 부모님 들 설레다 방 플랜카드 생각 하니 벅차다
# 4                    부모님 세계 여행 응원 대단 플랜카드 격리 창고 정리 센스 좋다
# ...                                                  ...
# 34451     붉다 메일  해외 여행 국내 해외여행  방식 영상 국내 유명 곳 여행 때 십년 같다
# 34452  영월 선돌 한반도 지형 붉다 메밀 꽃밭 카카오 네 비 주소 안 영월군 목골 마을 안...
# 34453                         영월 강추 여행지 감히 한마디 하자 청령포 추가
# 34454                               붉다 메밀 어디가 볼 수  주소 궁금
# 34455                                          메일 연락 어렵다
#
#                          reply_clean_mecab_withoutregion
# 0      해당  수익금 일부 민국 의료진 기부 상황 사태 조심 모두 격리 사회 거리 두기 신...
# 1                        가족 뉴 공항 철저 격리 절차 과정 시국 모습 부모 존경
# 2                                            평소 조카 삼촌 사람
# 3                                    눈물 부모 아들 방 플랜 카드 생각
# 4                            부모 세계  응원 플랜 카드 격리 창고 정리 센스
# ...                                                  ...
# 34451                                   일 해외   해외 방식
# 34452       영월 선돌 한반도 지형 밀꽃 밭 카카오 네비 주소 영월군 목골 마을 네비 주소
# 34453                                  영월 강추  한마디 청령포 추가
# 34454                                               밀 주소
# 34455                                               일 연락
#
# [31322 rows x 14 columns]

# %%
pattern = '쏘|곳|이|때|추천|킴스|번|곽|메|유|인|전|대|소개|국내'
df_youtube_comments['reply_clean_mecab'] = df_youtube_comments['reply_clean_mecab'].str.replace(pattern, '', regex=True)

# %%
from wordcloud import WordCloud
from collections import Counter

# %% [markdown]
# ### 연도별로 힐링/예약의 빈도 count

# %%
df_sheets_2024
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df_sheets_2024
#
# NameError: name 'df_sheets_2024' is not defined

# %%
healing_counts = df_youtube_comments[df_youtube_comments['reply_clean_mecab'].str.contains('힐링')].groupby('date_year').size()
healing_counts
# Out:
# date_year
# 2019     90
# 2020    254
# 2021    349
# 2022    239
# 2023    129
# 2024     29
# dtype: int64

# %%
reservation_counts = df_youtube_comments[df_youtube_comments['reply_clean_mecab'].str.contains('예약')].groupby('date_year').size()
reservation_counts
# Out:
# date_year
# 2019      8
# 2020     13
# 2021     21
# 2022     67
# 2023    211
# 2024     59
# dtype: int64

# %%
import seaborn as sns

# %%
plt.title("연도별 '힐링' 등장 빈도")
sns.barplot(data=healing_counts)
# Out:
# <Axes: title={'center': "연도별 '힐링' 등장 빈도"}, xlabel='date_year'>

# %%
plt.title("연도별 '예약' 등장 빈도")
sns.barplot(data=reservation_counts)
# Out:
# <Axes: title={'center': "연도별 '예약' 등장 빈도"}, xlabel='date_year'>

# %% [markdown]
# #### 2019

# %%
highlighted_words = ["예약"]

def custom_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    if word in highlighted_words:
        return "green"  # 특정 단어 색상
    else:
        return "gray"   # 나머지 단어 색상

# %%
df_sheets_2019 = []
for sheet_name, df in df_youtube_comments.query("date_year == 2019")['reply_clean_mecab'].items() :
  df_sheets_2019.append(df)

# %%
text = ' '.join(map(str, df_sheets_2019))
text_split = text.split()
text_split_count = Counter(text_split)

# %%
top_30 = pd.Series(text_split_count).sort_values(ascending=False)[:50]

# %%
wordCloud = WordCloud(color_func=custom_color_func, background_color="white", font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf').generate_from_frequencies(top_30)

# %%
wordCloud.words_
# Out:
# {'경주': 1.0,
#  '가을': 0.9324324324324325,
#  '밀양': 0.7972972972972973,
#  '길': 0.7905405405405406,
#  '사람': 0.7094594594594594,
#  '힐링': 0.6621621621621622,
#  '겨울': 0.6418918918918919,
#  '설명': 0.6351351351351351,
#  '행복': 0.6148648648648649,
#  '주': 0.6148648648648649,
#  '생각': 0.5945945945945946,
#  '풍경': 0.5878378378378378,
#  '코스': 0.5878378378378378,
#  '집': 0.581081081081081,
#  '음악': 0.5743243243243243,
#  '다음': 0.5608108108108109,
#  '언니': 0.5608108108108109,
#  '최고': 0.5608108108108109,
#  '시간': 0.5472972972972973,
#  '친구': 0.5067567567567568,
#  '눈': 0.49324324324324326,
#  '한국': 0.44594594594594594,
#  '제주도': 0.44594594594594594,
#  '도움': 0.44594594594594594,
#  '맛집': 0.4391891891891892,
#  '제주': 0.4391891891891892,
#  '말': 0.4391891891891892,
#  '덕분': 0.4391891891891892,
#  '앞': 0.43243243243243246,
#  '꽃': 0.43243243243243246,
#  '사진': 0.43243243243243246,
#  '도': 0.42567567567567566,
#  '순천': 0.41216216216216217,
#  '부탁': 0.40540540540540543,
#  '날': 0.39864864864864863,
#  '트래블': 0.39864864864864863,
#  '안녕': 0.3918918918918919,
#  '여름': 0.38513513513513514,
#  '느낌': 0.3716216216216216,
#  '단양': 0.3581081081081081,
#  '단풍': 0.35135135135135137,
#  '공원': 0.35135135135135137,
#  '사': 0.35135135135135137,
#  '기': 0.34459459459459457,
#  '마음': 0.33783783783783783,
#  '마을': 0.3310810810810811,
#  '빵': 0.3310810810810811,
#  '카페': 0.3310810810810811,
#  '정도': 0.31756756756756754,
#  '바다': 0.31756756756756754}

# %%
import matplotlib.pyplot as plt
plt.imshow(wordCloud)
plt.axis('off')
plt.title("2019년")
plt.show()

# %% [markdown]
# - 가을, 경주, 밀양, 길, 사람, 힐링
# - 19년도엔 가을, 경주, 밀양에 관심이 많았다.

# %% [markdown]
# #### 2020

# %%
df_sheets_2020 = []
for sheet_name, df in df_youtube_comments.query("date_year == 2020")['reply_clean_mecab'].items() :
  df_sheets_2020.append(df)

# %%
text = ' '.join(map(str, df_sheets_2020))

# %%
text_split = text.split()
text_split_count = Counter(text_split)

# %%
top_30 = pd.Series(text_split_count).sort_values(ascending=False)[:50]

# %%
wordCloud = WordCloud(color_func=custom_color_func, background_color="white", font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf').generate_from_frequencies(top_30)

# %%
plt.imshow(wordCloud)
plt.axis('off')
plt.title("2020년")
plt.show()

# %% [markdown]
# - 힐링, 길, 사람, 통영, 부산, 친구, 코로나
# - 이때부터 힐링 여행이 떠오르기 시작한 것으로 예상

# %% [markdown]
# #### 2021

# %%
df_sheets_2021 = []
for sheet_name, df in df_youtube_comments.query("date_year == 2021")['reply_clean_mecab'].items() :
  df_sheets_2021.append(df)

# %%
text = ' '.join(map(str, df_sheets_2021))
text_split = text.split()
text_split_count = Counter(text_split)

# %%
top_30 = pd.Series(text_split_count).sort_values(ascending=False)[:50]

# %%
wordCloud = WordCloud(color_func=custom_color_func, background_color="white", font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf').generate_from_frequencies(top_30)
wordCloud.words_
# Out:
# {'건강': 1.0,
#  '힐링': 0.9207161125319693,
#  '길': 0.8644501278772379,
#  '부산': 0.8439897698209718,
#  '집': 0.7416879795396419,
#  '기': 0.7033248081841432,
#  '서울': 0.6930946291560103,
#  '생각': 0.6624040920716112,
#  '울산': 0.6240409207161125,
#  '사람': 0.6163682864450127,
#  '시간': 0.59846547314578,
#  '해외': 0.5907928388746803,
#  '최고': 0.5856777493606138,
#  '덕분': 0.5754475703324808,
#  '응원': 0.5524296675191815,
#  '행복': 0.5294117647058824,
#  '풍경': 0.5166240409207161,
#  '예천': 0.4859335038363171,
#  '가을': 0.4782608695652174,
#  '다음': 0.46547314578005117,
#  '코스': 0.42710997442455245,
#  '한국': 0.4219948849104859,
#  '친구': 0.4219948849104859,
#  '촬영': 0.41687979539641945,
#  '공원': 0.40664961636828645,
#  '앞': 0.40153452685422,
#  '모습': 0.3989769820971867,
#  '일상': 0.3938618925831202,
#  '고향': 0.391304347826087,
#  '일': 0.38107416879795397,
#  '코로나': 0.36061381074168797,
#  '다행': 0.35805626598465473,
#  '여수': 0.3554987212276215,
#  '자연': 0.35294117647058826,
#  '마음': 0.3350383631713555,
#  '음악': 0.3273657289002558,
#  '눈': 0.32225063938618925,
#  '안동': 0.3145780051150895,
#  '날': 0.31202046035805625,
#  '끝': 0.3069053708439898,
#  '나라': 0.30434782608695654,
#  '정도': 0.30434782608695654,
#  '잼': 0.30179028132992325,
#  '구경': 0.29923273657289,
#  '산': 0.2966751918158568,
#  '고생': 0.29411764705882354,
#  '바다': 0.2915601023017903,
#  '수술': 0.2864450127877238,
#  '말': 0.27877237851662406,
#  '감동': 0.27365728900255754}

# %%
plt.imshow(wordCloud)
plt.axis('off')
plt.figtext(0.5, 0.22, "2021년", ha="center", fontsize=12, verticalalignment='top')
plt.show()

# %% [markdown]
# - 건강, 힐링, 부산, 서울, 집, 울산
# - 20년부터 코로나로 인해 지친 사람들이 건강, 힐링 여행을 많이 찾았던 것으로 예상

# %% [markdown]
# #### 2022

# %%
df_sheets_2022 = []
for sheet_name, df in df_youtube_comments.query("date_year == 2022")['reply_clean_mecab'].items() :
  df_sheets_2022.append(df)

# %%
text = ' '.join(map(str, df_sheets_2022))
text_split = text.split()
text_split_count = Counter(text_split)

# %%
top_30 = pd.Series(text_split_count).sort_values(ascending=False)[:50]

# %%
wordCloud = WordCloud(color_func=custom_color_func, background_color="white", font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf').generate_from_frequencies(top_30)

# %%
plt.imshow(wordCloud)
plt.axis('off')
plt.figtext(0.5, 0.22, "2022년", ha="center", fontsize=12, verticalalignment='top')
plt.show()

# %% [markdown]
# - 건강, 사람, 힐링, 부산, 시간

# %% [markdown]
# #### 2023

# %%
df_sheets_2023 = []
for sheet_name, df in df_youtube_comments.query("date_year == 2023")['reply_clean_mecab'].items() :
  df_sheets_2023.append(df)

# %%
text = ' '.join(map(str, df_sheets_2023))
text_split = text.split()
text_split_count = Counter(text_split)

# %%
top_30 = pd.Series(text_split_count).sort_values(ascending=False)[:50]

# %%
highlighted_words = ["예약"]

def custom_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    if word in highlighted_words:
        return "green"  # 특정 단어 색상
    else:
        return "gray"   # 나머지 단어 색상

# %%
wordcloud = WordCloud(color_func=custom_color_func, background_color="white", font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf').generate_from_frequencies(top_30)
wordcloud.words_
# Out:
# {'예약': 1.0,
#  '길': 0.9175627240143369,
#  '시간': 0.6881720430107527,
#  '가격': 0.6810035842293907,
#  '부산': 0.6451612903225806,
#  '사람': 0.6308243727598566,
#  '생각': 0.5555555555555556,
#  '가능': 0.5555555555555556,
#  '최고': 0.5519713261648745,
#  '주차장': 0.5197132616487455,
#  '집': 0.5053763440860215,
#  '나라': 0.4946236559139785,
#  '산': 0.4910394265232975,
#  '힐링': 0.4767025089605735,
#  '한국': 0.4731182795698925,
#  '주차': 0.4659498207885305,
#  '용': 0.46236559139784944,
#  '주': 0.44802867383512546,
#  '응원': 0.4336917562724014,
#  '설명': 0.40860215053763443,
#  '무료': 0.4050179211469534,
#  '풍경': 0.4050179211469534,
#  '정도': 0.4050179211469534,
#  '말': 0.3942652329749104,
#  '폭포': 0.3870967741935484,
#  '행복': 0.36917562724014336,
#  '눈': 0.3548387096774194,
#  '돈': 0.35125448028673834,
#  '덕분': 0.33691756272401435,
#  '꽃': 0.32974910394265233,
#  '크루즈': 0.32974910394265233,
#  '가을': 0.32616487455197135,
#  '날': 0.32616487455197135,
#  '다음': 0.3225806451612903,
#  '계곡': 0.3225806451612903,
#  '촬영': 0.3154121863799283,
#  '부탁': 0.3046594982078853,
#  '코스': 0.3010752688172043,
#  '멋': 0.3010752688172043,
#  '구경': 0.2974910394265233,
#  '일': 0.2939068100358423,
#  '공원': 0.2903225806451613,
#  '자연': 0.2867383512544803,
#  '주소': 0.2867383512544803,
#  '기': 0.2867383512544803,
#  '일본': 0.2831541218637993,
#  '건강': 0.27598566308243727,
#  '숙박': 0.27598566308243727,
#  '벚꽃': 0.2724014336917563,
#  '식사': 0.2724014336917563}

# %%
plt.imshow(wordcloud)
plt.axis('off')
plt.figtext(0.5, 0.22, "2023년", ha="center", fontsize=12, verticalalignment='top')
plt.show()

# %% [markdown]
# - 예약, 가격, 시간, 길, 부산, 생각
# - 23년에는 부산 여행을 많이 갔다? -> 단순히 부산 여행 영상의 댓글이 많았을 수도 있음
# - 주로 예약하는듯

# %% [markdown]
# #### 2024

# %%
df_sheets_2024 = []
for sheet_name, df in df_youtube_comments.query("date_year == 2024")['reply_clean_mecab'].items() :
  df_sheets_2024.append(df)

# %%
text = ' '.join(map(str, df_sheets_2024))
text_split = text.split()
text_split_count = Counter(text_split)

# %%
text_split_count
# Out:
# Counter({'장가': 93,
#          '예약': 71,
#          '행복': 52,
#          '사람': 39,
#          '벚꽃': 37,
#          '정선': 36,
#          '시간': 35,
#          '기차': 34,
#          '응원': 33,
#          '가능': 33,
#          '눈': 33,
#          '최고': 33,
#          '덕분': 31,
#          '생각': 30,
#          '힐링': 29,
#          '겨울': 28,
#          '호텔': 27,
#          '채널': 26,
#          '제주': 26,
#          '구경': 26,
#          '길': 25,
#          '주말': 24,
#          '정도': 24,
#          '굿': 23,
#          '가격': 23,
#          '패키지': 23,
#          '봄': 22,
#          '다음': 22,
#          '자': 22,
#          '산': 22,
#          '일': 21,
#          '용': 21,
#          '말': 21,
#          '가족': 21,
#          '열차': 21,
#          '올해': 20,
#          '코스': 20,
#          '마음': 20,
#          '날': 19,
#          '식사': 19,
#          '음식': 19,
#          '버스': 19,
#          '꽃': 18,
#          '날씨': 18,
#          '부탁': 18,
#          '출렁다리': 18,
#          '수고': 17,
#          '거': 17,
#          '풍경': 17,
#          '앞': 17,
#          '안녕': 16,
#          '기억': 16,
#          '건강': 16,
#          '혼자': 16,
#          '튜버': 16,
#          '자연': 16,
#          '한라산': 16,
#          '집': 16,
#          '설명': 15,
#          '비': 15,
#          '제주도': 15,
#          '차': 15,
#          '중국': 15,
#          '만족': 15,
#          '계획': 15,
#          '일정': 15,
#          '친': 14,
#          '고생': 14,
#          '매력': 14,
#          '바다': 14,
#          '기': 14,
#          '사랑': 14,
#          'ㄷ': 14,
#          '드론': 14,
#          '일상': 14,
#          '숙박': 14,
#          '부분': 13,
#          '추억': 13,
#          '뷰': 13,
#          '사': 13,
#          '상': 13,
#          '주차': 13,
#          '방법': 13,
#          '개': 12,
#          '방문': 12,
#          '사진': 12,
#          '모습': 12,
#          '숙소': 12,
#          '세상': 12,
#          '캠핑': 12,
#          '끝': 12,
#          '배': 12,
#          '리': 12,
#          '잔도': 12,
#          '평일': 12,
#          '반': 11,
#          '안내': 11,
#          '서울': 11,
#          '도움': 11,
#          '블로그': 11,
#          '화': 11,
#          '느낌': 11,
#          '여': 11,
#          '도': 11,
#          '설경': 11,
#          '친구': 11,
#          '주': 11,
#          '박': 11,
#          '하루': 11,
#          '한국': 11,
#          '출발': 11,
#          '가성': 11,
#          '쇼핑': 11,
#          '옵션': 11,
#          '명소': 11,
#          '감상': 10,
#          '시청': 10,
#          '가': 10,
#          '삶': 10,
#          '작년': 10,
#          '튜브': 10,
#          '동': 10,
#          '트': 10,
#          '멋': 10,
#          '나라': 10,
#          '경치': 10,
#          '주차장': 10,
#          '후회': 9,
#          '감': 9,
#          '몸': 9,
#          '고향': 9,
#          '미': 9,
#          '목소리': 9,
#          '예': 9,
#          '저녁': 9,
#          '입': 9,
#          '얼마': 9,
#          '당': 9,
#          '여름': 9,
#          '밤': 9,
#          '카라': 9,
#          '투어': 9,
#          '커플': 9,
#          '내년': 9,
#          '참고': 9,
#          '생': 9,
#          '추가': 9,
#          '맛': 9,
#          '협곡': 9,
#          '촬영': 9,
#          '온라': 9,
#          '포함': 9,
#          '돈': 9,
#          '파파': 9,
#          '비용': 9,
#          '달': 8,
#          '시기': 8,
#          '채': 8,
#          '공': 8,
#          '장소': 8,
#          '처음': 8,
#          '주행': 8,
#          '엔젤': 8,
#          '최근': 8,
#          '리나': 8,
#          '화팅': 8,
#          '안': 8,
#          '가요': 8,
#          'ㄱ': 8,
#          '운': 8,
#          '광고': 8,
#          '위험': 8,
#          '시장': 8,
#          '남': 8,
#          '뒤': 8,
#          '낭만': 8,
#          '나': 8,
#          '아': 8,
#          '점': 8,
#          '애': 8,
#          '준비': 8,
#          '환상': 8,
#          '체험': 8,
#          '성비': 8,
#          '무료': 8,
#          '상품': 8,
#          '아우라지': 8,
#          '강릉': 8,
#          '동해': 8,
#          '보물': 8,
#          '계절': 7,
#          '표': 7,
#          '내용': 7,
#          '말씀': 7,
#          '클릭': 7,
#          '힘': 7,
#          '행운': 7,
#          '기원': 7,
#          '장': 7,
#          '시작': 7,
#          '간': 7,
#          '감성': 7,
#          '조심': 7,
#          '등산': 7,
#          '무리': 7,
#          '방': 7,
#          '그': 7,
#          '속': 7,
#          '기회': 7,
#          '지역': 7,
#          '애견': 7,
#          '동반': 7,
#          '턴': 7,
#          '금요일': 7,
#          '강원도': 7,
#          '반려': 6,
#          '팁': 6,
#          '부산': 6,
#          '도래': 6,
#          '언니': 6,
#          '마지막': 6,
#          '앤젤리나': 6,
#          '후': 6,
#          '댓글': 6,
#          '름': 6,
#          '옆': 6,
#          '정상': 6,
#          '외국': 6,
#          '순간': 6,
#          '불편': 6,
#          '국': 6,
#          '호강': 6,
#          '해안': 6,
#          '기준': 6,
#          '공원': 6,
#          '애기': 6,
#          '펜션': 6,
#          '식당': 6,
#          '모텔': 6,
#          '객실': 6,
#          '밖': 6,
#          '감포': 6,
#          '켄싱': 6,
#          '거제': 6,
#          '자체': 6,
#          '속도': 6,
#          '가드': 6,
#          '예매': 6,
#          '청량리': 6,
#          '마곡사': 6,
#          '당일치기': 5,
#          '익': 5,
#          '비리': 5,
#          '세계': 5,
#          '코레': 5,
#          '제목': 5,
#          '감동': 5,
#          '연': 5,
#          '캡틴': 5,
#          '오랜만': 5,
#          '짱': 5,
#          '벗': 5,
#          '술': 5,
#          '진심': 5,
#          '침': 5,
#          '남자': 5,
#          '꿈': 5,
#          '설': 5,
#          '라산': 5,
#          '책': 5,
#          '스타': 5,
#          '신': 5,
#          '분위기': 5,
#          '와우': 5,
#          '지금': 5,
#          '화장실': 5,
#          '편안': 5,
#          '물': 5,
#          '신청': 5,
#          '절경': 5,
#          '연화': 5,
#          '미국': 5,
#          '지척': 5,
#          '할': 5,
#          '마을': 5,
#          '검색': 5,
#          '동굴': 5,
#          '선': 5,
#          '운영': 5,
#          '필수': 5,
#          '숲': 5,
#          '점심': 5,
#          '원': 5,
#          '스테크': 5,
#          '본': 5,
#          '서비스': 5,
#          '금액': 5,
#          '단점': 5,
#          '관광': 5,
#          '교회': 5,
#          '부부': 5,
#          '병': 5,
#          '미끄럼틀': 5,
#          '다리': 5,
#          '케블카': 5,
#          '천문': 5,
#          '아리랑': 5,
#          '해외': 5,
#          '정선아리랑': 5,
#          '주산지': 5,
#          '스타일': 4,
#          '나날': 4,
#          '안젤리나': 4,
#          '나레션': 4,
#          '처제': 4,
#          '외모': 4,
#          '야기': 4,
#          '복': 4,
#          '결혼': 4,
#          '저': 4,
#          '급': 4,
#          '동안': 4,
#          '노': 4,
#          '브': 4,
#          '편집': 4,
#          '나무': 4,
#          '바람': 4,
#          '양': 4,
#          '컨디션': 4,
#          '정': 4,
#          '역': 4,
#          '얘기': 4,
#          '선생': 4,
#          '연속': 4,
#          '사친': 4,
#          '터짐': 4,
#          '영혼': 4,
#          '등록': 4,
#          '투': 4,
#          '시절': 4,
#          '걱정': 4,
#          '요즘': 4,
#          '게': 4,
#          '문제': 4,
#          '설정': 4,
#          '일본': 4,
#          '발': 4,
#          '필요': 4,
#          '집사람': 4,
#          '강': 4,
#          '카페': 4,
#          '바닷가': 4,
#          '모': 4,
#          '하늘': 4,
#          '기분': 4,
#          '잔': 4,
#          '소리': 4,
#          '뉴욕': 4,
#          '경관': 4,
#          '산책로': 4,
#          '산책': 4,
#          '정성': 4,
#          '경': 4,
#          '거리': 4,
#          '프로그램': 4,
#          '바베큐': 4,
#          '공간': 4,
#          '사장': 4,
#          '레스토랑': 4,
#          '비수기': 4,
#          '공장': 4,
#          '친절': 4,
#          '장갑': 4,
#          '손': 4,
#          '시': 4,
#          '경남': 4,
#          '트래블': 4,
#          '최악': 4,
#          '예정': 4,
#          '룸': 4,
#          '수영장': 4,
#          '괴산': 4,
#          '수': 4,
#          '시설': 4,
#          '금지': 4,
#          '반찬': 4,
#          '성': 4,
#          '근처': 4,
#          '사트': 4,
#          '복음': 4,
#          '상상': 4,
#          '직항': 4,
#          '구매': 4,
#          '입장료': 4,
#          '중간': 4,
#          '운행': 4,
#          '용기': 4,
#          '시골': 4,
#          '구': 4,
#          '스위스': 4,
#          '영동선': 4,
#          '태백': 4,
#          '충남': 4,
#          '금산': 4,
#          '코비가': 4,
#          '하동': 4,
#          '견동': 3,
#          '삼종': 3,
#          '세트': 3,
#          '시차': 3,
#          '희망': 3,
#          '쯤': 3,
#          '봄날': 3,
#          '녹산': 3,
#          '광': 3,
#          '양매': 3,
#          '화마': 3,
#          '구례': 3,
#          '오': 3,
#          '정리': 3,
#          '남쪽': 3,
#          '수도': 3,
#          '법': 3,
#          '장난': 3,
#          '첨': 3,
#          '공기': 3,
#          '예술': 3,
#          '등반': 3,
#          '주공': 3,
#          '튜바': 3,
#          '고독': 3,
#          '아내': 3,
#          '자리': 3,
#          '얼굴': 3,
#          '힌': 3,
#          '잼': 3,
#          '덕': 3,
#          '혼': 3,
#          '연애': 3,
#          '손예진': 3,
#          '중요': 3,
#          '머리': 3,
#          '폭설': 3,
#          '화면': 3,
#          '살': 3,
#          '목': 3,
#          '문구': 3,
#          '영화': 3,
#          '맘': 3,
#          '다행': 3,
#          '문': 3,
#          '형': 3,
#          '앞부분': 3,
#          '섭외': 3,
#          '심': 3,
#          '관계': 3,
#          '장면': 3,
#          '담': 3,
#          '스윗': 3,
#          '취미': 3,
#          '누나': 3,
#          '탈출': 3,
#          '그림': 3,
#          '상태': 3,
#          '라면': 3,
#          '낭': 3,
#          '잡념': 3,
#          '소식': 3,
#          '오랫만': 3,
#          '빠': 3,
#          '노숙': 3,
#          '별': 3,
#          '시즌': 3,
#          '골': 3,
#          '캠': 3,
#          '버': 3,
#          '확': 3,
#          '김': 3,
#          '가운데': 3,
#          '미혼': 3,
#          '후반': 3,
#          '티비': 3,
#          '자신': 3,
#          '보름달': 3,
#          '제': 3,
#          '꽃길': 3,
#          '옷': 3,
#          '송도': 3,
#          '용궁': 3,
#          '암': 3,
#          '거창': 3,
#          '주소': 3,
#          '봉': 3,
#          '계곡': 3,
#          '섬': 3,
#          '태안': 3,
#          '재미': 3,
#          '바': 3,
#          '쌤': 3,
#          '아침': 3,
#          '당일': 3,
#          '요금': 3,
#          '렌터카': 3,
#          '가입': 3,
#          '생태': 3,
#          '풀': 3,
#          '신안군': 3,
#          '장봉': 3,
#          '허가': 3,
#          '아들': 3,
#          '변산반도': 3,
#          '탐': 3,
#          '글': 3,
#          '참여': 3,
#          '료': 3,
#          '장관': 3,
#          '실': 3,
#          '호': 3,
#          '가구': 3,
#          '마들렌': 3,
#          '텔': 3,
#          '직원': 3,
#          '커피': 3,
#          '트레블': 3,
#          '리모': 3,
#          '요리': 3,
#          '맥주': 3,
#          '소주': 3,
#          '한시': 3,
#          '기본': 3,
#          '최': 3,
#          '주변': 3,
#          '냄새': 3,
#          '링': 3,
#          '수준': 3,
#          '틀': 3,
#          '과': 3,
#          '조식': 3,
#          '벤트': 3,
#          '엄마': 3,
#          '부모': 3,
#          '모임': 3,
#          '완': 3,
#          '고민': 3,
#          '표현': 3,
#          '음주': 3,
#          '취사': 3,
#          '경주': 3,
#          '횟집': 3,
#          '회': 3,
#          '동네': 3,
#          '휴양림': 3,
#          '목요일': 3,
#          '일요일': 3,
#          '경비': 3,
#          '비행': 3,
#          '리무진': 3,
#          '시내': 3,
#          '공항': 3,
#          '청': 3,
#          '군더더기': 3,
#          '신비': 3,
#          '감탄': 3,
#          '사용': 3,
#          '선택': 3,
#          '붕어빵': 3,
#          '가을': 3,
#          '진행': 3,
#          '적용': 3,
#          '요정': 3,
#          '경험': 3,
#          '민둥산역': 3,
#          '승차': 3,
#          '영월': 3,
#          '도시락': 3,
#          '자차': 3,
#          '신토불': 3,
#          '정선선': 3,
#          '양평': 3,
#          '강원': 3,
#          '관광버스': 3,
#          '황금': 3,
#          '서산': 3,
#          '쌍': 3,
#          '홍문': 3,
#          '구문소': 3,
#          '청송': 3,
#          '공주': 3,
#          '영암': 3,
#          '부여': 3,
#          '보령': 3,
#          '홍도': 3,
#          '임실': 2,
#          '변산': 2,
#          '도서관': 2,
#          '통도사': 2,
#          '근': 2,
#          '동물': 2,
#          '르': 2,
#          '맛집': 2,
#          '릉원': 2,
#          '모험가': 2,
#          '정원': 2,
#          '중교통': 2,
#          '데트': 2,
#          '매화꽃': 2,
#          '자막': 2,
#          '님': 2,
#          '화요일': 2,
#          '제철': 2,
#          '아쉬움': 2,
#          '행복감': 2,
#          '보람': 2,
#          '엄지': 2,
#          '지방': 2,
#          '강연': 2,
#          '젊음': 2,
#          '미소': 2,
#          '웃음': 2,
#          '쓰': 2,
#          '체력': 2,
#          '기약': 2,
#          '새해': 2,
#          '존': 2,
#          '만': 2,
#          '파도': 2,
#          '형부': 2,
#          '쟁': 2,
#          '누님': 2,
#          '앤젤': 2,
#          '시선': 2,
#          '김현철': 2,
#          '아저씨': 2,
#          '공감': 2,
#          '활동': 2,
#          '환승': 2,
#          '결혼식': 2,
#          '근황': 2,
#          '우정': 2,
#          '줄': 2,
#          '리액션': 2,
#          '식': 2,
#          '조': 2,
#          '청춘': 2,
#          '클라밍': 2,
#          '않': 2,
#          '눈꽃': 2,
#          '산행': 2,
#          '의지': 2,
#          '감기': 2,
#          '연휴': 2,
#          '설중': 2,
#          '재난': 2,
#          '담날': 2,
#          '포기': 2,
#          '정신': 2,
#          '머리카락': 2,
#          '궁': 2,
#          '성판악': 2,
#          '통제': 2,
#          '관음사': 2,
#          '하산': 2,
#          '관련': 2,
#          '의식': 2,
#          '설산': 2,
#          '팬': 2,
#          '오라버니': 2,
#          '결': 2,
#          '찬성': 2,
#          '극': 2,
#          '한달': 2,
#          '실력': 2,
#          '아파': 2,
#          '짐': 2,
#          '머슴': 2,
#          '정미': 2,
#          '배우': 2,
#          '폼': 2,
#          '블루드래곤': 2,
#          '아재': 2,
#          '컷': 2,
#          '스토리': 2,
#          '콤': 2,
#          '샤랄': 2,
#          '모드': 2,
#          '생애': 2,
#          '새': 2,
#          '굳': 2,
#          '무릎': 2,
#          '한편': 2,
#          '자랑': 2,
#          '간접': 2,
#          '남친': 2,
#          '아기': 2,
#          '썸': 2,
#          '홈': 2,
#          '색감': 2,
#          '해변': 2,
#          '집시': 2,
#          '밤하늘': 2,
#          '캉': 2,
#          '모자': 2,
#          '사고': 2,
#          '애청자': 2,
#          '천장': 2,
#          '우도': 2,
#          '핑장': 2,
#          '회사': 2,
#          '반지': 2,
#          '위치': 2,
#          '길바닥': 2,
#          '해결': 2,
#          '체코': 2,
#          '욕심': 2,
#          '아가씨': 2,
#          '물가': 2,
#          '방송': 2,
#          '명': 2,
#          '요청': 2,
#          '절': 2,
#          '구리': 2,
#          '야영장': 2,
#          '취향': 2,
#          '밑': 2,
#          '그릇': 2,
#          '아래': 2,
#          '평소': 2,
#          '슐': 2,
#          '랭': 2,
#          '왕': 2,
#          '구름다리': 2,
#          '폭포': 2,
#          '추암': 2,
#          '촛바위': 2,
#          '영종': 2,
#          '경기': 2,
#          '하차': 2,
#          '천주산': 2,
#          '임꺽정': 2,
#          '봇도랑': 2,
#          '두타산': 2,
#          '데크': 2,
#          '벼랑': 2,
#          '행정': 2,
#          '기관': 2,
#          '지자체': 2,
#          '속초': 2,
#          '향기': 2,
#          '솔향기': 2,
#          '외옹치항': 2,
#          '잎': 2,
#          '크': 2,
#          '로바': 2,
#          '꽃말': 2,
#          '네잎': 2,
#          '크로': 2,
#          '가본': 2,
#          '원래': 2,
#          '드라브': 2,
#          '수정': 2,
#          '오후': 2,
#          '당황': 2,
#          '연화도': 2,
#          '최저': 2,
#          '프로': 2,
#          '혜택': 2,
#          '풍도': 2,
#          '서우': 2,
#          'ㅅ': 2,
#          '조랑말': 2,
#          '작업': 2,
#          '방원': 2,
#          '의무': 2,
#          '부안': 2,
#          '젼': 2,
#          '잼버리': 2,
#          '부': 2,
#          '불가': 2,
#          '국립': 2,
#          '공단': 2,
#          '성수기': 2,
#          '사방': 2,
#          '로또': 2,
#          '매진': 2,
#          '연락처': 2,
#          '벌': 2,
#          '뉴스': 2,
#          '노래': 2,
#          '나중': 2,
#          '물놀': 2,
#          '배경': 2,
#          '밥': 2,
#          '세끼': 2,
#          '제공': 2,
#          '오픈': 2,
#          '창문': 2,
#          '침구류': 2,
#          '큐브': 2,
#          '청결': 2,
#          '뉴': 2,
#          '피자': 2,
#          '구성': 2,
#          '홍보': 2,
#          '마드': 2,
#          '미온수': 2,
#          '업주': 2,
#          '욕': 2,
#          '주세요': 2,
#          '조금': 2,
#          '패스': 2,
#          '값': 2,
#          '적정': 2,
#          '차원': 2,
#          '국가': 2,
#          '사우나': 2,
#          '비갑': 2,
#          '노력': 2,
#          '자녀': 2,
#          '체': 2,
#          '청소년': 2,
#          '바비큐': 2,
#          '흡연': 2,
#          '단체': 2,
#          '티': 2,
#          '갈매기': 2,
#          '은근': 2,
#          '민박': 2,
#          '한잔': 2,
#          '소': 2,
#          '토요일': 2,
#          '교통': 2,
#          '주민': 2,
#          '경북': 2,
#          '속리산': 2,
#          '조카': 2,
#          '체크': 2,
#          '은혜': 2,
#          '예배': 2,
#          '플랜': 2,
#          '아고다': 2,
#          '리스트': 2,
#          '무주': 2,
#          '함양': 2,
#          '주장': 2,
#          '어른': 2,
#          '구역': 2,
#          '콘텐츠': 2,
#          '캔': 2,
#          '동일': 2,
#          '베': 2,
#          '협찬': 2,
#          '적극': 2,
#          '층': 2,
#          '확률': 2,
#          '건물': 2,
#          '떡': 2,
#          '보통': 2,
#          '링크': 2,
#          '특': 2,
#          '통주': 2,
#          '선물': 2,
#          '장사': 2,
#          '면세점': 2,
#          '현지': 2,
#          '경우': 2,
#          '가방': 2,
#          '감탄사': 2,
#          '광경': 2,
#          '기록': 2,
#          '현실': 2,
#          '우': 2,
#          '랜': 2,
#          '웅장': 2,
#          '엘베': 2,
#          '목표': 2,
#          '터': 2,
#          '리석': 2,
#          '조절': 2,
#          '손가락': 2,
#          '도착': 2,
#          '개발': 2,
#          '계림': 2,
#          '명절': 2,
#          '조선족': 2,
#          '안개': 2,
#          '조마': 2,
#          '베리': 2,
#          '버킷': 2,
#          '관광객': 2,
#          '강제': 2,
#          '문의': 2,
#          '리잔': 2,
#          '고소공포증': 2,
#          '역사': 2,
#          '환경': 2,
#          '참': 2,
#          '딸': 2,
#          '모노레일': 2,
#          '답변': 2,
#          '기사': 2,
#          '증': 2,
#          '현': 2,
#          '군': 2,
#          '금강산': 2,
#          '새벽': 2,
#          '강매': 2,
#          '구간': 2,
#          '가슴': 2,
#          '설례': 2,
#          '소통': 2,
#          '알고리즘': 2,
#          '중학생': 2,
#          '사북': 2,
#          '회원': 2,
#          '왕복': 2,
#          '주요': 2,
#          '양평역': 2,
#          '관광열차': 2,
#          '학교': 2,
#          '남편': 2,
#          '사촌': 2,
#          '청량리역': 2,
#          '벽': 2,
#          '노선': 2,
#          '배차': 2,
#          '볼거리': 2,
#          '밀양': 2,
#          '원주': 2,
#          '기차표': 2,
#          '탑승': 2,
#          '자거': 2,
#          '음성': 2,
#          '디자': 2,
#          '연락': 2,
#          '상세': 2,
#          '남해': 2,
#          '보리암': 2,
#          '문화재': 2,
#          '복곡': 2,
#          '바위': 2,
#          '암초': 2,
#          '네스코': 2,
#          '명승': 2,
#          '포천': 2,
#          '우리나라': 2,
#          '축제': 2,
#          '월출산': 2,
#          '진실': 2,
#          '오르막길': 2,
#          '내리막길': 2,
#          '발휘': 2,
#          '겹벚꽃': 2,
#          '지난주': 2,
#          '안동': 2,
#          '가로수': 2,
#          '양쪽': 2,
#          '어마': 2,
#          '차량': 2,
#          '저수지': 2,
#          '홍': 2,
#          '영남': 1,
#          '등나무': 1,
#          '작약': 1,
#          '샤스타': 1,
#          '데지': 1,
#          '천북': 1,
#          '마당': 1,
#          '마산': 1,
#          '진해': 1,
#          '창원': 1,
#          '목련': 1,
#          '남지': 1,
#          '밭': 1,
#          '연지': 1,
#          '못': 1,
#          '만년교': 1,
#          '입장': 1,
#          '여부': 1,
#          '진안': 1,
#          '조치원': 1,
#          '조천': 1,
#          '천변': 1,
#          '종시': 1,
#          '오른쪽': 1,
#          '밑부분': 1,
#          '로요': 1,
#          '무료입장': 1,
#          '순천': 1,
#          '동편': 1,
#          '정할': 1,
#          '절정': 1,
#          '닭': 1,
#          '서시': 1,
#          '산동': 1,
#          '구례읍': 1,
#          '토박': 1,
#          '일부': 1,
#          '갈증': 1,
#          '박수': 1,
#          '마중': 1,
#          ...})

# %%
top_30 = pd.Series(text_split_count).sort_values(ascending=False)[:30]

# %%
highlighted_words = ["예약"]

def custom_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    if word in highlighted_words:
        return "green"  # 특정 단어 색상
    else:
        return "gray"   # 나머지 단어 색상

# %%
wordcloud = WordCloud(color_func=custom_color_func, background_color="white", font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf').generate_from_frequencies(top_30)

# %%
wordCloud.words_
# Out:
# {'건강': 1.0,
#  '사람': 0.7905027932960894,
#  '기': 0.7653631284916201,
#  '시간': 0.7402234636871509,
#  '배': 0.7011173184357542,
#  '힐링': 0.6871508379888268,
#  '부산': 0.6368715083798883,
#  '행복': 0.6005586592178771,
#  '생각': 0.5782122905027933,
#  '다음': 0.5782122905027933,
#  '응원': 0.5614525139664804,
#  '한국': 0.5586592178770949,
#  '최고': 0.5391061452513967,
#  '집': 0.5335195530726257,
#  '제주': 0.5083798882681564,
#  '일': 0.4972067039106145,
#  '차': 0.4860335195530726,
#  '모습': 0.4553072625698324,
#  '길': 0.4441340782122905,
#  '풍경': 0.43854748603351956,
#  '덕분': 0.4273743016759777,
#  '앞': 0.4273743016759777,
#  '마음': 0.39664804469273746,
#  '포항': 0.39664804469273746,
#  '울릉도': 0.39385474860335196,
#  '라산': 0.388268156424581,
#  '고향': 0.3687150837988827,
#  '바다': 0.3575418994413408,
#  '가을': 0.3575418994413408,
#  '촬영': 0.34916201117318435,
#  '나라': 0.34916201117318435,
#  '상': 0.3324022346368715,
#  '제주도': 0.329608938547486,
#  '말': 0.32122905027932963,
#  '정도': 0.31564245810055863,
#  '서울': 0.30446927374301674,
#  '기억': 0.3016759776536313,
#  '주소': 0.2988826815642458,
#  '예약': 0.2988826815642458,
#  '코스': 0.29608938547486036,
#  '오랜만': 0.29329608938547486,
#  '다행': 0.2905027932960894,
#  '익산': 0.2877094972067039,
#  '해외': 0.2877094972067039,
#  '가족': 0.2849162011173184,
#  '박': 0.2849162011173184,
#  '음식': 0.28212290502793297,
#  '마을': 0.276536312849162,
#  '일상': 0.276536312849162,
#  '가격': 0.26536312849162014}

# %%
plt.imshow(wordcloud)
plt.axis("off")
plt.figtext(0.5, 0.22, "2024년", ha="center", fontsize=12, verticalalignment='top')
plt.show()

# %% [markdown]
# - 장가, 예약, 행복, 사람, 벚꽃, 기차
# - 24년이 아직 5월초이므로 겨울, 벚꽃이 많이 나타나는 것으로 예상
# - 마찬가지로, 예약이 크게 나타나는 이유는 상반기에 예약을 잡고 하반기에 여행을 가기 때문으로 예상

# %% [markdown]
# ### season
# - 워드클라우드 결과가 계절별 유의미하게 구분되지 않음
# - 영상 업로드 날짜와 영상 촬영일에 차이가 있을 수 있으므로 분석 정확하지 않음

# %%
df_youtube_comments['date_month'].value_counts()
# Out:
# date_month
# 5     3728
# 6     3589
# 10    3530
# 9     3123
# 4     3027
# 11    2926
# 7     2830
# 3     1960
# 1     1864
# 12    1760
# 2     1621
# 8     1364
# Name: count, dtype: int64

# %% [markdown]
# - 12, 1, 2 winter
# - 3, 4, 5 spring
# - 6, 7, 8 summer
# - 9, 10, 11 fall

# %%
seasons = {
    12: '겨울', 1: '겨울', 2: '겨울',
    3: '봄', 4: '봄', 5: '봄',
    6: '여름', 7: '여름', 8: '여름',
    9: '가을', 10: '가을', 11: '가을'
}
df_youtube_comments['season'] = df_youtube_comments['date_month'].map(seasons)

# %%
df_youtube_comments['season'].value_counts()
# Out:
# season
# 가을    9579
# 봄     8715
# 여름    7783
# 겨울    5245
# Name: count, dtype: int64

# %% [markdown]
# #### 봄

# %%
df_sheets = []
for sheet_name, df in df_youtube_comments.query("season == '봄'")['reply_clean_mecab'].items() :
  df_sheets.append(df)

# %%
text = ' '.join(map(str, df_sheets))
text_split = text.split()
text_split_count = Counter(text_split)

# %%
top_30 = pd.Series(text_split_count).sort_values(ascending=False)[:30]

# %%
wordCloud = WordCloud(background_color='white', font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf')
wordCloud.generate_from_frequencies(top_30)

# %%
plt.imshow(wordCloud)
plt.axis('off')
plt.show()

# %% [markdown]
# #### 여름

# %%
df_sheets = []
for sheet_name, df in df_youtube_comments.query("season == '여름'")['reply_clean_mecab'].items() :
  df_sheets.append(df)

# %%
text = ' '.join(map(str, df_sheets))
text_split = text.split()
text_split_count = Counter(text_split)

# %%
top_30 = pd.Series(text_split_count).sort_values(ascending=False)[:30]

# %%
wordCloud = WordCloud(background_color='white', font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf')
wordCloud.generate_from_frequencies(top_30)

# %%
plt.imshow(wordCloud)
plt.axis('off')
plt.show()

# %% [markdown]
# #### 가을

# %%
df_sheets = []
for sheet_name, df in df_youtube_comments.query("season == '가을'")['reply_clean_mecab'].items() :
  df_sheets.append(df)

# %%
text = ' '.join(map(str, df_sheets))
text_split = text.split()
text_split_count = Counter(text_split)

# %%
top_30 = pd.Series(text_split_count).sort_values(ascending=False)[:30]

# %%
wordCloud = WordCloud(background_color='white', font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf')
wordCloud.generate_from_frequencies(top_30)

# %%
plt.imshow(wordCloud)
plt.axis('off')
plt.show()

# %% [markdown]
# #### 겨울

# %%
df_sheets = []
for sheet_name, df in df_youtube_comments.query("season == '겨울'")['reply_clean_mecab'].items() :
  df_sheets.append(df)

# %%
text = ' '.join(map(str, df_sheets))
text_split = text.split()
text_split_count = Counter(text_split)

# %%
top_30 = pd.Series(text_split_count).sort_values(ascending=False)[:30]

# %%
wordCloud = WordCloud(background_color='white', font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf')
wordCloud.generate_from_frequencies(top_30)

# %%
plt.imshow(wordCloud)
plt.axis('off')
plt.show()
