# %%
import pandas as pd
import pymongo
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('font', family='NanumBarunGothic') # 혹은 다른 설치한 Nanum 폰트 사용
import scipy
import scipy.stats as stats

client=pymongo.MongoClient("192.168.10.240",27017)
db= client['AI_LKJ']
yeomi_review = db['yeomi_review']
yeomi_review = yeomi_review.find()
yeomi_review = pd.DataFrame(yeomi_review)
kto9suk9suk_review = db['kto9suk9suk_review']
kto9suk9suk_review = kto9suk9suk_review.find()
kto9suk9suk_review = pd.DataFrame(kto9suk9suk_review)

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ## 여행에 미치다 페이지에서 국내 여행 게시글만 가져오기

# %%
list_region = ['#강원','#경기','#경남','#경북','#광주','#대구','#대전','#부산','#서울','#세종','#울산','#인천','#전남','#전북','#제주','#충남','#충북','#강릉','#고성','#동해','#삼척','#속초','#양구','#양양','#영월','#원주','#인제','#정선','#철원','#춘천','#태백','#평창','#홍천','#화천','#횡성','#가평','#고양','#과천','#광명','#광주','#구리','#군포','#김포','#남양주','#동두천','#부천','#성남','#수원','#시흥','#안산','#안성','#안양','#양주','#양평','#여주','#연천','#오산','#용인','#의왕','#의정부','#이천','#파주','#평택','#포천','#하남','#화성','#거제','#거창','#고성','#김해','#남해','#밀양','#사천','#산청','#양산','#의령','#진주','#창녕','#창원','#통영','#하동','#함안','#함양','#합천','#경산','#경주','#고령','#구미','#김천','#문경','#봉화','#상주','#성주','#안동','#영덕','#영양','#영주','#영천','#예천','#울릉','#울진','#의성','#청도','#청송','#칠곡','#포항','#광산','#남구','#동구','#북구','#서구','#군위','#남구','#달서','#달성','#동구','#북구','#서구','#수성','#중구','#대덕','#동구','#서구','#유성','#중구','#강서','#금정','#기장','#남구','#동구','#동래','#부산진','#북구','#사상','#사하','#서구','#수영','#연제','#영도','#중구','#해운대','#강남','#강동','#강북','#강서','#관악','#광진','#구로','#금천','#노원','#도봉','#동대문','#동작','#마포','#서대문','#서초','#성동','#성북','#송파','#양천','#영등포','#용산','#은평','#종로','#중구','#중랑','#남구','#동구','#북구','#울주','#중구','#강화','#계양','#남동','#동구','#미추홀','#부평','#서구','#연수','#옹진','#중구','#강진','#고흥','#곡성','#광양','#구례','#나주시','#담양','#목포','#무안','#보성','#순천','#신안','#여수','#영광','#영암','#완도','#장성','#장흥','#진도','#함평','#해남','#화순','#고창','#군산','#김제','#남원','#무주','#부안','#순창','#완주','#익산','#임실','#장수','#전주','#정읍','#진안','#서귀포','#제주','#계룡','#공주','#금산','#논산','#당진','#보령','#부여','#서산','#서천','#아산','#예산','#천안','#청양','#태안','#홍성','#괴산','#단양','#보은','#영동','#옥천','#음성','#제천','#증평','#진천','#청주','#충주']
korea_trip = []
for i in yeomi_review[yeomi_review['review_content'].isna()]['card_content']:
    for j in list_region:
        if j in i:
            korea_trip.append(i)
            break
condition_region = f"card_content in {korea_trip}"
korea_yeomi_review = yeomi_review.query(condition_region)
korea_yeomi_review
# Out:
#                               _id  \
# 201      65f9bf4f08bfcc46ca193606
# 202      65f9bf4f08bfcc46ca193607
# 203      65f9bf4f08bfcc46ca193608
# 204      65f9bf5008bfcc46ca193609
# 205      65f9bf5008bfcc46ca19360a
# ...                           ...
# 1152424  662b80e0f231019cd5b61943
# 1152425  662b80e0f231019cd5b61944
# 1152426  662b80e0f231019cd5b61945
# 1152427  662b80e1f231019cd5b61946
# 1152428  662b80e1f231019cd5b61947
#
#                                               card_content     card_date  \
# 201      .\n#인제, #Inje, #대한민국, #Korea\n.\n.\n자작나무 숲 분위기...  2018년 1월 22일
# 202      .\n#인제, #Inje, #대한민국, #Korea\n.\n.\n자작나무 숲 분위기...  2018년 1월 22일
# 203      .\n#인제, #Inje, #대한민국, #Korea\n.\n.\n자작나무 숲 분위기...  2018년 1월 22일
# 204      .\n#인제, #Inje, #대한민국, #Korea\n.\n.\n자작나무 숲 분위기...  2018년 1월 22일
# 205      .\n#인제, #Inje, #대한민국, #Korea\n.\n.\n자작나무 숲 분위기...  2018년 1월 22일
# ...                                                    ...           ...
# 1152424  일단 저장!📩 서울에서 데이트, 야장, 피크닉까지 쌈@뽕하게 즐기는 방법😜\n\n서...  2024년 4월 26일
# 1152425  일단 저장!📩 서울에서 데이트, 야장, 피크닉까지 쌈@뽕하게 즐기는 방법😜\n\n서...  2024년 4월 26일
# 1152426  일단 저장!📩 서울에서 데이트, 야장, 피크닉까지 쌈@뽕하게 즐기는 방법😜\n\n서...  2024년 4월 26일
# 1152427  일단 저장!📩 서울에서 데이트, 야장, 피크닉까지 쌈@뽕하게 즐기는 방법😜\n\n서...  2024년 4월 26일
# 1152428  일단 저장!📩 서울에서 데이트, 야장, 피크닉까지 쌈@뽕하게 즐기는 방법😜\n\n서...  2024년 4월 26일
#
#         card_like card_watch  check_point  \
# 201          7447             BePBx_qBqwm
# 202          7447             BePBx_qBqwm
# 203          7447             BePBx_qBqwm
# 204          7447             BePBx_qBqwm
# 205          7447             BePBx_qBqwm
# ...           ...        ...          ...
# 1152424       123             C6OA2Fbhy5r
# 1152425       123             C6OA2Fbhy5r
# 1152426       123             C6OA2Fbhy5r
# 1152427       123             C6OA2Fbhy5r
# 1152428       123             C6OA2Fbhy5r
#
#                                     review_content   review_date
# 201                                            NaN           NaN
# 202                                   @shorokhofff  2018년 6월 22일
# 203                @soye0114 여기 다니엘 뮤비 찍은곳인가???!!!  2018년 2월 24일
# 204                            @h.a.ing 요기봐 ㅋㅋㅋㅋㅋㅋ   2018년 2월 8일
# 205                        @dal.hye 야 나 여기 가고싶어ㅠㅠㅠ  2018년 1월 28일
# ...                                            ...           ...
# 1152424                                        NaN           NaN
# 1152425                                   미츠바 좋습니당  2024년 4월 26일
# 1152426                          와 이제 곧 장미공원의 시즌이다  2024년 4월 26일
# 1152427  혹시 여기 다 가본 사람 있어? 어디가 젤 좋았는지 추천해주라줘~🙋🏻‍♀️  2024년 4월 26일
# 1152428         @ddohing_ 장미공원ㅅㅂㅋㅋㅋ 존나 쪄죽을뻔한거 기억나노  2024년 4월 26일
#
# [473220 rows x 8 columns]

# %% [markdown]
# ## 구석구석 페이지와 여행에 미치다 페이지에서 가져온 데이터 합치기

# %%
kto9suk9suk_review
# Out:
#                              _id  \
# 0       65f99f8608bfcc46ca19351d
# 1       65f99f8608bfcc46ca19351e
# 2       65f99f8608bfcc46ca19351f
# 3       65f99f8808bfcc46ca193520
# 4       65f99f8b08bfcc46ca193521
# ...                          ...
# 125933  662a1fb44a4fe5fadf3f71ee
# 125934  662f1d43b33c9dc30aa95f3f
# 125935  662f1d4bb33c9dc30aa95f40
# 125936  662f22cb5cb025207273f6f6
# 125937  662f22d15cb025207273f6f7
#
#                                              card_content     card_date  \
# 0       알려지지 않았다고 해서 가치가 없는 것은 아니다. 한 장의 사진으로 사랑 받게 된 ...  2014년 6월 23일
# 1       알려지지 않았다고 해서 가치가 없는 것은 아니다. 한 장의 사진으로 사랑 받게 된 ...  2014년 6월 23일
# 2       알려지지 않았다고 해서 가치가 없는 것은 아니다. 한 장의 사진으로 사랑 받게 된 ...  2014년 6월 23일
# 3       멋진 풍경과 감동, 여행과 휴식은 생각보다 가까운 곳에 있다. 부산 만덕 레고마을\...  2014년 6월 23일
# 4       유유자적 한가로이 풀을 뜯는 말 뒤편,\n걸려있는 구름마저도 평화로운 성산일출봉\n...  2014년 7월 10일
# ...                                                   ...           ...
# 125933  신규 개장 기념 무료 운영 중(~5/6)‼ 짜릿함 최고인😆 김천 #사계절썰매장\n\...  2024년 4월 25일
# 125934  제주도 토종 소, 흑한우 살짝 레어로 익혀 한 입에 쏘옥~!\n참 숯불로 구워 더욱...   2014년 8월 5일
# 125935  범선의 휘황찬란한 실루엣이 영덕 대게를 먹으러 찾는 방문객을 반기는 이곳 +_+ 대...  2014년 8월 26일
# 125936  제주도 토종 소, 흑한우 살짝 레어로 익혀 한 입에 쏘옥~!\n참 숯불로 구워 더욱...   2014년 8월 5일
# 125937  범선의 휘황찬란한 실루엣이 영덕 대게를 먹으러 찾는 방문객을 반기는 이곳 +_+ 대...  2014년 8월 26일
#
#        card_like card_watch  check_point review_content   review_date
# 0             50              pkcKuIzTJ0            NaN           NaN
# 1             50              pkcKuIzTJ0       정말 아름다워요   2014년 7월 9일
# 2             50              pkcKuIzTJ0        멋진 섬이네요  2014년 6월 24일
# 3             87              pk8YhwTTDR            NaN           NaN
# 4             42              qQx_BQTTBH            NaN           NaN
# ...          ...        ...          ...            ...           ...
# 125933       106             C6LYPKTSzun              🛷  2024년 4월 25일
# 125934        81              rT9rIsTTNs            NaN           NaN
# 125935       100              sJhwZxzTCf            NaN           NaN
# 125936        81              rT9rIsTTNs            NaN           NaN
# 125937       100              sJhwZxzTCf            NaN           NaN
#
# [125938 rows x 8 columns]

# %%
df_sns = pd.concat([kto9suk9suk_review, korea_yeomi_review], ignore_index=True)
df_sns
# Out:
#                              _id  \
# 0       65f99f8608bfcc46ca19351d
# 1       65f99f8608bfcc46ca19351e
# 2       65f99f8608bfcc46ca19351f
# 3       65f99f8808bfcc46ca193520
# 4       65f99f8b08bfcc46ca193521
# ...                          ...
# 599153  662b80e0f231019cd5b61943
# 599154  662b80e0f231019cd5b61944
# 599155  662b80e0f231019cd5b61945
# 599156  662b80e1f231019cd5b61946
# 599157  662b80e1f231019cd5b61947
#
#                                              card_content     card_date  \
# 0       알려지지 않았다고 해서 가치가 없는 것은 아니다. 한 장의 사진으로 사랑 받게 된 ...  2014년 6월 23일
# 1       알려지지 않았다고 해서 가치가 없는 것은 아니다. 한 장의 사진으로 사랑 받게 된 ...  2014년 6월 23일
# 2       알려지지 않았다고 해서 가치가 없는 것은 아니다. 한 장의 사진으로 사랑 받게 된 ...  2014년 6월 23일
# 3       멋진 풍경과 감동, 여행과 휴식은 생각보다 가까운 곳에 있다. 부산 만덕 레고마을\...  2014년 6월 23일
# 4       유유자적 한가로이 풀을 뜯는 말 뒤편,\n걸려있는 구름마저도 평화로운 성산일출봉\n...  2014년 7월 10일
# ...                                                   ...           ...
# 599153  일단 저장!📩 서울에서 데이트, 야장, 피크닉까지 쌈@뽕하게 즐기는 방법😜\n\n서...  2024년 4월 26일
# 599154  일단 저장!📩 서울에서 데이트, 야장, 피크닉까지 쌈@뽕하게 즐기는 방법😜\n\n서...  2024년 4월 26일
# 599155  일단 저장!📩 서울에서 데이트, 야장, 피크닉까지 쌈@뽕하게 즐기는 방법😜\n\n서...  2024년 4월 26일
# 599156  일단 저장!📩 서울에서 데이트, 야장, 피크닉까지 쌈@뽕하게 즐기는 방법😜\n\n서...  2024년 4월 26일
# 599157  일단 저장!📩 서울에서 데이트, 야장, 피크닉까지 쌈@뽕하게 즐기는 방법😜\n\n서...  2024년 4월 26일
#
#        card_like card_watch  check_point  \
# 0             50              pkcKuIzTJ0
# 1             50              pkcKuIzTJ0
# 2             50              pkcKuIzTJ0
# 3             87              pk8YhwTTDR
# 4             42              qQx_BQTTBH
# ...          ...        ...          ...
# 599153       123             C6OA2Fbhy5r
# 599154       123             C6OA2Fbhy5r
# 599155       123             C6OA2Fbhy5r
# 599156       123             C6OA2Fbhy5r
# 599157       123             C6OA2Fbhy5r
#
#                                    review_content   review_date
# 0                                             NaN           NaN
# 1                                        정말 아름다워요   2014년 7월 9일
# 2                                         멋진 섬이네요  2014년 6월 24일
# 3                                             NaN           NaN
# 4                                             NaN           NaN
# ...                                           ...           ...
# 599153                                        NaN           NaN
# 599154                                   미츠바 좋습니당  2024년 4월 26일
# 599155                          와 이제 곧 장미공원의 시즌이다  2024년 4월 26일
# 599156  혹시 여기 다 가본 사람 있어? 어디가 젤 좋았는지 추천해주라줘~🙋🏻‍♀️  2024년 4월 26일
# 599157         @ddohing_ 장미공원ㅅㅂㅋㅋㅋ 존나 쪄죽을뻔한거 기억나노  2024년 4월 26일
#
# [599158 rows x 8 columns]

# %% [markdown]
# ## 어느 지역에 관한 표시

# %%
region_gw = ['강원도 ','강원 ','강원특별자치도 ','#강원','#강릉', '#고성', '#동해', '#삼척', '#속초', '#양구', '#양양', '#영월', '#원주', '#인제', '#정선', '#철원', '#춘천', '#태백', '#평창', '#홍천', '#화천', '#횡성']
region_gg = ['경기도 ','경기 ','#경기','#가평', '#고양', '#과천', '#광명', '#구리', '#군포', '#김포', '#남양주', '#동두천', '#부천', '#성남', '#수원', '#시흥', '#안산', '#안성', '#안양', '#양주', '#양평', '#여주', '#연천', '#오산', '#용인', '#의왕', '#의정부', '#이천', '#파주', '#평택', '#포천', '#하남', '#화성']
region_gn = ['경상남도 ','경남 ','#경남 ','#거제', '#거창', '#고성', '#김해', '#남해', '#밀양', '#사천', '#산청', '#양산', '#의령', '#진주', '#창녕', '#창원', '통영', '#하동', '#함안', '#함양', '#합천']
region_gb = ['경상북도 ','경북 ','#경북','#경산', '#경주', '#고령', '#구미', '#김천', '#문경', '#봉화', '#상주', '#성주', '#안동', '#영덕', '#영양', '#영주', '#영천', '#예천', '#울릉', '#울진', '#의성', '#청도', '#청송', '#칠곡', '#포항']
region_gj = ['광주광역시 ','광주 ','#광주','#광산']
region_dg = ['대구광역시 ','대구 ','#대구','#군위', '#달서', '#달성', '#수성']
region_dj = ['대전광역시 ','대전 ','#대전','#대덕',   '#유성']
region_sj = ['세종특별자치시 ','세종 ','#세종']
region_bs = ['부산특별시 ','부산 ','#부산', '#금정', '#기장',  '#동래', '#부산진', '#사상', '#사하',  '#수영', '#연제', '#영도',  '#해운대']
region_su = ['서울특별시 ','서울 ','#서울','#강남', '#강동', '#강북', '#관악', '#광진', '#구로', '#금천', '#노원', '#도봉', '#동대문', '#동작', '#마포', '#서대문', '#서초', '#성동', '#성북', '#송파', '#양천', '#영등포', '#용산', '#은평', '#종로',  '#중랑']
region_us = ['울산광역시 ', '울산 ','#울산', '#울주']
region_ic = ['인천광역시 ','인천 ','#인천','#강화', '#계양', '#남동',  '#미추홀', '#부평',  '#연수', '#옹진']
region_jn = ['전라남도 ','전남 ','#강진', '#전남','#고흥', '#곡성', '#광양', '#구례', '#나주', '#담양', '#목포', '#무안', '#보성', '#순천', '#신안', '#여수', '#영광', '#영암', '#완도', '#장성', '#장흥', '#진도', '#함평', '#해남', '#화순']
region_jb = ['전라북도 ','전북 ','#고창', '#전북','#군산', '#김제', '#남원', '#무주', '#부안', '#순창', '#완주', '#익산', '#임실', '#장수', '#전주', '#정읍', '#진안']
region_jj = ['제주특별자치도 ','제주 ','#서귀포', '#제주']
region_cn = ['충청남도 ','충남 ','#충남','#계룡', '#공주', '#금산', '#논산', '#당진', '#보령', '#부여', '#서산', '#서천', '#아산', '#예산', '#천안', '#청양', '#태안', '#홍성']
region_cb = ['충청북도 ','충북 ','#충북','#괴산', '#단양', '#보은', '#영동', '#옥천', '#음성', '#제천', '#증평', '#진천', '#청주', '#충주']

# %%
from collections import Counter

for i in range(len(df_sns)):
    region_tour=[]
    city_tour = []
    for j in region_gw:
        if j in df_sns['card_content'][i]:
            region_tour.append('강원')
            city_tour.append(j)
    for j in region_gg:
        if j in df_sns['card_content'][i]:
            region_tour.append('경기')
            city_tour.append(j)
    for j in region_gn:
        if j in df_sns['card_content'][i]:
            region_tour.append('경남')
            city_tour.append(j)
    for j in region_gj:
        if j in df_sns['card_content'][i]:
            region_tour.append('광주')   
            city_tour.append(j)
    for j in region_gb:
        if j in df_sns['card_content'][i]:
            region_tour.append('경북')   
            city_tour.append(j)
    for j in region_sj:
        if j in df_sns['card_content'][i]:
            region_tour.append('세종')   
            city_tour.append(j)
    for j in region_dg:
        if j in df_sns['card_content'][i]:
            region_tour.append('대구')
            city_tour.append(j)
    for j in region_dj:
        if j in df_sns['card_content'][i]:
            region_tour.append('대전')
            city_tour.append(j)
    for j in region_bs:
        if j in df_sns['card_content'][i]:
            region_tour.append('부산')
            city_tour.append(j)
    for j in region_su:
        if j in df_sns['card_content'][i]:
            region_tour.append('서울')
            city_tour.append(j)
    for j in region_us:
        if j in df_sns['card_content'][i]:
            region_tour.append('울산')
            city_tour.append(j)
    for j in region_ic:
        if j in df_sns['card_content'][i]:
            region_tour.append('인천')
            city_tour.append(j)
    for j in region_jn:
        if j in df_sns['card_content'][i]:
            region_tour.append('전남')    
            city_tour.append(j)
    for j in region_jb:
        if j in df_sns['card_content'][i]:
            region_tour.append('전북')
            city_tour.append(j)
    for j in region_jj:
        if j in df_sns['card_content'][i]:
            region_tour.append('제주')
            city_tour.append(j)
    for j in region_cn:
        if j in df_sns['card_content'][i]:
            region_tour.append('충남')
            city_tour.append(j)
    for j in region_cb:
        if j in df_sns['card_content'][i]:
            region_tour.append('충북')
            city_tour.append(j)
    word_region = Counter(region_tour)
    most_common_region = word_region.most_common(1)
    most_common_region_keys = [word for word, count in most_common_region]
    word_city = Counter(city_tour)
    most_common_city = word_city.most_common(1)
    most_common_city_keys = [word for word, count in most_common_city]
    df_sns.loc[i, 'region'] = ", ".join(most_common_region_keys)
    df_sns.loc[i, 'city'] = ", ".join(city_tour)

# %% [markdown]
# ## 댓글에 관한 데이터와 제목에 관한 데이터 분류

# %%
df_sns_review = df_sns[df_sns['review_content'].notna()]
df_sns_title = df_sns[df_sns['review_content'].isna()]
df_sns_review = df_sns_review.reset_index()
df_sns_review
df_sns_title = df_sns_title.reset_index()
df_sns_title
# Out:
#        index                       _id  \
# 0          0  65f99f8608bfcc46ca19351d
# 1          3  65f99f8808bfcc46ca193520
# 2          4  65f99f8b08bfcc46ca193521
# 3          7  65f99f8d08bfcc46ca193524
# 4         11  65f99f8f08bfcc46ca193528
# ...      ...                       ...
# 5187  599013  662abcaaf231019cd5b60515
# 5188  599038  662abe16f231019cd5b60b80
# 5189  599137  662ada15f231019cd5b61622
# 5190  599140  662af284f231019cd5b61861
# 5191  599153  662b80e0f231019cd5b61943
#
#                                            card_content     card_date  \
# 0     알려지지 않았다고 해서 가치가 없는 것은 아니다. 한 장의 사진으로 사랑 받게 된 ...  2014년 6월 23일
# 1     멋진 풍경과 감동, 여행과 휴식은 생각보다 가까운 곳에 있다. 부산 만덕 레고마을\...  2014년 6월 23일
# 2     유유자적 한가로이 풀을 뜯는 말 뒤편,\n걸려있는 구름마저도 평화로운 성산일출봉\n...  2014년 7월 10일
# 3     울산 명선도의 불게 타오르는 노을과 해무의 장관\n마치 그림을 그려놓은듯한 풍경에 ...  2014년 7월 11일
# 4     비가 내린 후에야 진정한 모습을 드러내는 시무지기폭포\n이 비경을 만나러 가는 고된...  2014년 7월 12일
# ...                                                 ...           ...
# 5187  드디어 다음주, 국가권력급 벚꽃맛집 ‘여의도’ 봄꽃축제 개막 (뿌뿌-)\n\n누가 ...  2024년 3월 23일
# 5188  지금 제일 핫하다는 기안84 전시 ‘기안도(奇案島)’ 후기 🔥\n다들 여기서 기안8...  2024년 3월 26일
# 5189  지친 일상으로부터 벗어날 수 있는 시간, 응봉산에서 🌙\n\n이번 한주도 수고한 여...  2024년 4월 19일
# 5190  거창 여행 어떻게 할지 모르겠다고? 😎 여미가 직접 다녀와서 알려주는 [밥상의 여정...  2024년 4월 24일
# 5191  일단 저장!📩 서울에서 데이트, 야장, 피크닉까지 쌈@뽕하게 즐기는 방법😜\n\n서...  2024년 4월 26일
#
#      card_like card_watch  check_point review_content review_date region  \
# 0           50              pkcKuIzTJ0            NaN         NaN
# 1           87              pk8YhwTTDR            NaN         NaN     부산
# 2           42              qQx_BQTTBH            NaN         NaN     제주
# 3           58              qTGZrrzTAH            NaN         NaN     울산
# 4           39              qVtXCrTTIY            NaN         NaN     광주
# ...        ...        ...          ...            ...         ...    ...
# 5187      3091             C41qMeoBkpF            NaN         NaN     서울
# 5188      4752             C49-AnfBEhj            NaN         NaN     서울
# 5189      1530             C58BRwIhdW4            NaN         NaN     서울
# 5190      1288             C6I3IZBhfzp            NaN         NaN     경남
# 5191       123             C6OA2Fbhy5r            NaN         NaN     서울
#
#           city
# 0
# 1          부산
# 2          #제주
# 3     울산 , #울산
# 4     광주 , #광주
# ...        ...
# 5187  서울 , #서울
# 5188  서울 , #서울
# 5189  서울 , #서울
# 5190       #거창
# 5191  서울 , #서울
#
# [5192 rows x 11 columns]

# %%
pivot_review = pd.pivot_table(df_sns_review,index=['region','card_content','card_date','card_like','card_watch'],values='_id',aggfunc='count')
df_sns_title = pivot_review.reset_index()

# %%
len(df_sns_title)
# Out:
# 4652

# %%
def split(text):
    new_text = text.replace("#", " ")
    return " ".join(new_text.split())

# %%
df_sns_title.loc[:,'card_content'] = df_sns_title['card_content'].apply(split)

# %% [markdown]
# ## 계절별로 분류

# %%
for i in range(len(df_sns_title)):
    df_sns_title.loc[i,'card_month'] = df_sns_title.loc[i,'card_date'].split()[1][:-1]
    if df_sns_title.loc[i,'card_date'].split()[1][:-1] in ['3','4','5']:
        df_sns_title.loc[i,'card_season'] = '봄'
    elif df_sns_title.loc[i,'card_date'].split()[1][:-1] in ['6','7','8']:
        df_sns_title.loc[i,'card_season']  = '여름'
    elif df_sns_title.loc[i,'card_date'].split()[1][:-1] in ['9','10','11']:
        df_sns_title.loc[i,'card_season']  = '가을'
    elif df_sns_title.loc[i,'card_date'].split()[1][:-1] in ['12','1','2']:
        df_sns_title.loc[i,'card_season'] = '겨울'

# %%
# 토크나이징 함수 정의
list_region = ['강원','경기','경남','경북','광주','대구','대전','부산','서울','세종','울산','인천','전남','전북','제주','충남','충북','강릉','고성','동해','삼척','속초','양구','양양','영월','원주','인제','정선','철원','춘천','태백','평창','홍천','화천','횡성','가평','고양','과천','광명','광주','구리','군포','김포','남양주','동두천','부천','성남','수원','시흥','안산','안성','안양','양주','양평','여주','연천','오산','용인','의왕','의정부','이천','파주','평택','포천','하남','화성','거제','거창','고성','김해','남해','밀양','사천','산청','양산','의령','진주','창녕','창원','통영','하동','함안','함양','합천','경산','경주','고령','구미','김천','문경','봉화','상주','성주','안동','영덕','영양','영주','영천','예천','울릉','울진','의성','청도','청송','칠곡','포항','광산','남구','동구','북구','서구','군위','남구','달서','달성','동구','북구','서구','수성','중구','대덕','동구','서구','유성','중구','강서','금정','기장','남구','동구','동래','부산진','북구','사상','사하','서구','수영','연제','영도','중구','해운대','강남','강동','강북','강서','관악','광진','구로','금천','노원','도봉','동대문','동작','마포','서대문','서초','성동','성북','송파','양천','영등포','용산','은평','종로','중구','중랑','남구','동구','북구','울주','중구','강화','계양','남동','동구','미추홀','부평','서구','연수','옹진','중구','강진','고흥','곡성','광양','구례','나주시','담양','목포','무안','보성','순천','신안','여수','영광','영암','완도','장성','장흥','진도','함평','해남','화순','고창','군산','김제','남원','무주','부안','순창','완주','익산','임실','장수','전주','정읍','진안','서귀포','제주','계룡','공주','금산','논산','당진','보령','부여','서산','서천','아산','예산','천안','청양','태안','홍성','괴산','단양','보은','영동','옥천','음성','제천','증평','진천','청주','충주']
stopwords = ['맛집','스팟','사람','공간','포토','자체','시작','장소','정도','마을','마음','확인','무료','방문','풍경','가능','일상','모습','지금','소개','선정','방법','스냅','해시태그','여행지','추천','기간','인생','거리','두기','인스타그램','그램','스타','여행','국내','사진','트래블','공사','공모전','구석구석','이벤트','참여','당첨','발표','오늘','이번','주차','주차장','이용','요금','방역','리더','봄','여름','가을','겨울','시간','제공','모두','위치','관광','운영','요즘','최고','준수','영상','촬영']
stopwords.extend(list_region) 
from konlpy.tag import Okt
okt = Okt()
from mecab import MeCab
mecab = MeCab()
def Tokenizer(raw, pos=["Noun"], stopword=stopwords):
    word_list = []
    for word, tag in okt.pos(raw,norm=True,stem=True):
        if len(word) > 1 and tag in pos and word not in stopword:
            if mecab.pos(word)[0][1] in ["NNG"]:
                word_list.append(word)
    return " ".join(word_list)

# %%
df_sns_title.loc[:,'card_content_clean']=df_sns_title['card_content'].apply(Tokenizer)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidfVectorizer = TfidfVectorizer(use_idf=True,max_df=0.5,min_df=0.02,ngram_range=(1,2))
features = tfidfVectorizer.fit_transform(df_sns_title['card_content_clean'])
features.toarray()[:2]
dictionary_list = tfidfVectorizer.get_feature_names_out()
dictionary_list
# Out:
# array(['가족', '가지', '감상', '감성', '개인', '게시', '경험', '계절', '곳곳', '공식', '공원',
#        '관람', '광고', '구경', '그림', '근처', '금요일', '기분', '기상', '기준', '길이', '나무',
#        '날씨', '낭만', '내용', '노을', '느낌', '다리', '다음', '단풍', '대표', '데이트', '도착',
#        '동화', '드라이브', '등산', '라면', '랜선', '마감', '마지막', '만끽', '매력', '매일',
#        '명소', '문화', '물결', '바람', '바위', '박물관', '배경', '벚꽃', '봄꽃', '분위기', '사랑',
#        '사실', '사용', '사이', '사회', '산책', '산책로', '상황', '생각', '선물', '성인', '세계',
#        '세상', '소리', '숙소', '스토리', '시즌', '식당', '아래', '아침', '안전', '야경', '야외',
#        '어린이', '에메랄드', '여유', '여행자', '역사', '예술', '예약', '예정', '오픈', '오후',
#        '올해', '완료', '월요일', '음료', '음식', '이름', '이상', '이후', '인스타', '일몰', '일정',
#        '일출', '입장', '입장료', '자랑', '자리', '자연', '저녁', '전망대', '전시', '전통', '절경',
#        '절벽', '정보', '정상', '정원', '제한', '조금', '주말', '주변', '준비', '지역', '직접',
#        '진행', '참고', '청소년', '체험', '초록', '최대', '추억', '축제', '친구', '커피', '코스',
#        '태그', '테마', '투어', '파크', '평일', '폭포', '필수', '하늘', '하루', '한눈', '해변',
#        '해수욕장', '해안', '현장', '현재', '호수', '홈페이지', '환상', '활용', '휴무', '힐링'],
#       dtype=object)

# %%
from sklearn.decomposition import LatentDirichletAllocation
lda_model_10 = LatentDirichletAllocation(n_components=3, random_state=36) #인스턴스화 #n_components 토픽의 갯수
lda_model_10.fit(features)
import pandas as pd
pd.set_option('display.max_colwidth', None)
## 상위 단어 추출 
## 0 확률 1은 dictionary
topics_list = list()
for topic in lda_model_10.components_:
    df_datas = [topic, dictionary_list]
    df_topics = pd.DataFrame(data=df_datas)
    df_topics= df_topics.T
    df_topics = df_topics.sort_values(0, ascending=False)
    # print(df_topics[:3])
    topics_text = ' '.join(df_topics[1].values[:5])# 시리즈 형식으로 출력 get values from series / index 
    topics_list.append(topics_text)
topics_list_add_10 = [['Topic1', 'Topic2','Topic3'],topics_list]
df_topics_keywords_10 = pd.DataFrame(topics_list_add_10)
df_topics_keywords_10=df_topics_keywords_10.T
df_topics_keywords_10
# Out:
#          0                 1
# 0   Topic1    축제 주말 체험 가족 매일
# 1   Topic2    공원 벚꽃 야경 코스 해변
# 2   Topic3  데이트 노을 분위기 힐링 사랑
# 3   Topic4              None
# 4   Topic5              None
# 5   Topic6              None
# 6   Topic7              None
# 7   Topic8              None
# 8   Topic9              None
# 9  Topic10              None

# %%
list_topics = []
for i in range(len(lda_model_10.components_)):
    df_datas_0 = [lda_model_10.components_[i], dictionary_list]
    df_topics_0 = pd.DataFrame(data=df_datas_0).T
    df_topics_0 = df_topics_0.dropna()
    df_topics_0 = df_topics_0.sort_values(0, ascending=False).reset_index()
    df_topics_0.rename(columns = {1 : i+1}, inplace = True)
    df_topics_0.rename(columns = {0 : 'score'}, inplace = True)
    list_topics.append(df_topics_0.loc[:4,['score',i+1]])
df_topic = pd.concat(list_topics,axis=1)
df_topic
# Out:
#         score   1       score   2       score    3
# 0  182.860866  축제  199.862967  공원  148.486447  데이트
# 1  112.429357  주말  132.931282  벚꽃  146.608159   노을
# 2  100.952032  체험  117.730883  야경  110.353142  분위기
# 3   69.972178  가족  100.959124  코스   81.333902   힐링
# 4   65.183632  매일  100.132097  해변    78.30132   사랑

# %%
import pyLDAvis
import pyLDAvis.lda_model
vis_10 = pyLDAvis.lda_model.prepare(lda_model_10,features,tfidfVectorizer)
vis_10
pyLDAvis.enable_notebook()
components_10_display = pyLDAvis.display(vis_10)
components_10_display
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el186921402032114920328005053865" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el186921402032114920328005053865_data = {"mdsDat": {"x": [0.26505761474332495, -0.03679070685018306, -0.22826690789314208], "y": [0.09744238819349339, -0.2510532347010973, 0.1536108465076039], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [34.33242702649378, 33.599217726268996, 32.06835524723722]}, "tinfo": {"Term": ["\uacf5\uc6d0", "\ucd95\uc81c", "\ubc9a\uaf43", "\ub370\uc774\ud2b8", "\uc57c\uacbd", "\ub178\uc744", "\uc8fc\ub9d0", "\ubd84\uc704\uae30", "\ud574\ubcc0", "\uccb4\ud5d8", "\uc804\ub9dd\ub300", "\ub2e8\ud48d", "\uce5c\uad6c", "\uc0ac\ub791", "\uc0b0\ucc45", "\ub2e4\ub9ac", "\uac00\uc871", "\ud574\uc218\uc695\uc7a5", "\ud558\ub298", "\ub9e4\uc77c", "\ucee4\ud53c", "\uc219\uc18c", "\uc77c\ucd9c", "\uc608\uc57d", "\uc785\uc7a5", "\ud3ed\ud3ec", "\uc785\uc7a5\ub8cc", "\uac10\uc131", "\ucd08\ub85d", "\uc624\ud508", "\ucd95\uc81c", "\uc8fc\ub9d0", "\uac00\uc871", "\uc785\uc7a5", "\ub9e4\uc77c", "\uc219\uc18c", "\uc608\uc57d", "\ubd04\uaf43", "\uc804\uc2dc", "\uc131\uc778", "\uc624\ud508", "\uc138\uacc4", "\ub9c8\uac10", "\ubc15\ubb3c\uad00", "\uad00\ub78c", "\uc785\uc7a5\ub8cc", "\uc0c1\ud669", "\uc608\uc220", "\uc5b4\ub9b0\uc774", "\ud3c9\uc77c", "\uc5ed\uc0ac", "\ud648\ud398\uc774\uc9c0", "\uccad\uc18c\ub144", "\ud604\uc7ac", "\ud604\uc7a5", "\uae30\uc0c1", "\uc138\uc0c1", "\uacf5\uc2dd", "\ud734\ubb34", "\uccb4\ud5d8", "\ub3d9\ud654", "\uc6d4\uc694\uc77c", "\uae08\uc694\uc77c", "\uc9c4\ud589", "\ub4dc\ub77c\uc774\ube0c", "\ubb38\ud654", "\uc62c\ud574", "\ucc38\uace0", "\uba85\uc18c", "\ucd94\uc5b5", "\uc790\uc5f0", "\uce5c\uad6c", "\uc77c\ucd9c", "\ucd08\ub85d", "\ud22c\uc5b4", "\ubd84\uc704\uae30", "\uc5ec\ud589\uc790", "\ub370\uc774\ud2b8", "\ud0dc\uadf8", "\uac8c\uc2dc", "\ud574\uc218\uc695\uc7a5", "\uc815\uc0c1", "\ub0b4\uc6a9", "\uc2a4\ud1a0\ub9ac", "\uc644\ub8cc", "\ud65c\uc6a9", "\uc0ac\ud68c", "\ub4f1\uc0b0", "\uc18c\ub9ac", "\ubc14\uc704", "\uc800\ub141", "\uc790\ub791", "\uc0ac\ub791", "\ub178\uc744", "\uad11\uace0", "\uac10\uc131", "\uc774\ub984", "\uc2dd\ub2f9", "\ub2e4\uc74c", "\uc2dc\uc98c", "\uc0ac\uc2e4", "\ub0a0\uc528", "\ud790\ub9c1", "\ubc14\ub78c", "\ub9e4\ub825", "\ub9c8\uc9c0\ub9c9", "\uae30\ubd84", "\uc77c\ubab0", "\ud558\ub298", "\ubc9a\uaf43", "\uc57c\uacbd", "\uacf5\uc6d0", "\ub2e8\ud48d", "\uc804\ub9dd\ub300", "\ud3ed\ud3ec", "\ud574\ubcc0", "\ud638\uc218", "\uc74c\uc2dd", "\ub77c\uba74", "\uc808\ubcbd", "\uc0b0\ucc45\ub85c", "\ub2e4\ub9ac", "\ucee4\ud53c", "\uc5d0\uba54\ub784\ub4dc", "\uae38\uc774", "\uc0b0\ucc45", "\ud558\ub8e8", "\uc808\uacbd", "\uc0dd\uac01", "\uc790\ub9ac", "\uc5ec\uc720", "\ud658\uc0c1", "\ud574\uc548", "\ub098\ubb34", "\ud55c\ub208", "\uc8fc\ubcc0", "\uac10\uc0c1", "\ucf54\uc2a4", "\ub290\ub08c", "\ud558\ub298", "\uadf8\ub9bc", "\uc815\uc6d0", "\uba85\uc18c"], "Freq": [200.0, 180.0, 133.0, 145.0, 118.0, 150.0, 111.0, 108.0, 101.0, 102.0, 73.0, 72.0, 70.0, 78.0, 70.0, 67.0, 69.0, 68.0, 136.0, 65.0, 62.0, 63.0, 61.0, 62.0, 59.0, 54.0, 59.0, 72.0, 56.0, 57.0, 180.1792283114359, 110.7805910085544, 68.94604291193454, 58.56710136755871, 64.22772042683698, 62.71760126482711, 61.88561671376676, 48.190441098359685, 47.415800492052654, 46.03229490602925, 56.17962805645002, 52.97711177016194, 42.31604230981859, 40.93115142308929, 41.394074740389755, 58.85694201493672, 43.51980729854388, 39.9171783585381, 34.07560391654078, 35.47674484614398, 46.12626905799886, 32.902852813574974, 30.91598894055534, 41.49219098234855, 28.332240503434882, 26.604077472509303, 46.86126696840319, 25.330611478523757, 46.56828002100633, 99.47158026348197, 53.90015661881922, 36.78277076178431, 40.29932968425808, 53.973060084872614, 57.933659210613094, 48.81548041360674, 42.080184294312886, 41.53727528509901, 46.678822775881414, 41.15823616284792, 42.5883167028535, 69.6629685302696, 60.88021323042963, 55.26920467663451, 51.63080501878559, 106.65610538619781, 45.24382060842817, 143.511873390591, 38.88483863710638, 37.29817970566332, 66.61846989407573, 45.70767329226132, 35.480832773872905 ...

# %%
# grid_best_model.fit(features)
import pandas as pd
pd.set_option('display.max_colwidth', None)
## 상위 단어 추출 
## 0 확률 1은 dictionary
topics_list = list()
for topic in lda_model_10.components_:
    df_datas = [topic, dictionary_list]
    df_topics = pd.DataFrame(data=df_datas)
    df_topics= df_topics.T
    df_topics = df_topics.sort_values(0, ascending=False)

# %%
topics_output = lda_model_10.transform(features)
df_topics_score = pd.DataFrame(topics_output)
df_topics_score['dominant_topic_number']=np.argmax(topics_output, axis=1)
df_topics_score['dominant_topic_number'].value_counts()
# Out:
# dominant_topic_number
# 0    1848
# 2    1419
# 1    1385
# Name: count, dtype: int64

# %%
df_sns_title.loc[:,'content_topic'] = df_topics_score['dominant_topic_number']

# %%
df_sns_title.query("content_topic==0")
# Out:
#      region  \
# 0
# 1
# 2
# 3
# 4
# ...     ...
# 4644     충북
# 4645     충북
# 4649     충북
# 4650     충북
# 4651     충북
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     card_content  \
# 0                                                                                                                                                                                                                                                                                                                                                                                 "너에게 난 해질녘 노을처럼 한편의 아름다운 추억이 되고🎶" ⠀ 이 노을 완전 청춘드라마 재질(●ˇ∀ˇ●) 넓은 들판에 홀로 서있는 소나무와 아름다운 하늘이 조화를 이루는 이곳은 청주 정북동토성 ⠀ 나홀로나무는 정북동토성의 유명한 일몰 인생샷 스팟이에요. ⠀ 소중한 사람과 함께 지평선 너머 사라지는 태양을 보며 서로에게 아름다운 추억을 남겨보세요. ⠀ 우리 모두의 건강한 일상을 위해 생활속거리두기 수칙을 준수해주세요! ⠀ 🇰🇷 국내여행 은 대한민국구석구석 📷 다님 3기 남혁진 님
# 1                                                                                                                                                                                                                                2021년 신축년 에도 대.구.석과 함께 하시겠소?🐮 밝게 떠 오른 태양처럼 더없이 빛날 우리들의 새해 건강한 일상을 하루빨리 만나기 위해, 랜선해맞이 로 2021년을 맞이해 보아요! 거친 파도를 헤쳐나가는 한 척의 배처럼, 모두가 함께 이 어려움을 이겨내서 안정적인 제 자리로 돌아오길 소망합니다. 대한민국구석구석 은 올해에도 열심히 다채로운 ‘대한민국 구석구석’을 전해드릴게요! 여러분 모두 새해 복 많이 받으세요!🙇🏻‍♀️ 🙇🏻 📍 강원 강릉 정동진 일출 📷 @bigg_jun 님 ★코로나19 확산으로 일부 지역이 사회적거리두기 2.5단계로 격상되었습니다. (12/8~) 우리 모두 건강한 일상으로 돌아가기 위해 방역수칙을 준수해 주세요!
# 2                                                                                   colorful대구석 명예의 우수작을 소개합니다 ٩(ˊᗜˋ*)و ⠀ 대.구.석 지기는 여러분의 작품과 사진을 보며 상상력 풍부한 작품에 놀라기도, ⠀ 가족, 친구를 비롯한 소중한 사람과 함께 하는 모습을 보며 뿌듯하고 행복했어요 (ʃƪ ˘ ▽˘) ⠀ 대.구.석이 뜻했던 만큼, 부디 많은 분들이 여행하지 못하는 마음을 컬러링 으로 달래며 조금이나마 즐거운 시간이 되었길 바랍니다. ⠀ 아름다운 대한민국 구석구석을 정성껏 칠해 참여해주신 여러분 모두 감사합니다. 🎨예술왕 @yummm_in_ 님, @geurae90 님, @namji_0523 님, @you_gream 님, @inbi2.0 님 🎨개성상 @twinklejini 님, @geulzi_illust 님, @yellow._.mango 님, @dudghkfhdns 님, @carriecalli 님 ⠀ ★코로나19 확산으로 일부 지역이 사회적거리두기 2.5단계로 격상되었습니다. (12/8~) 우리 모두 건강한 일상으로 돌아가기 위해 방역수칙을 준수해 주세요!
# 3                                                         경남 남해 의 새로운 랜드마크 인 설리스카이워크 의 매직아워 풍경 드론샷 ! 일몰 후 광원이 사라진 그 찰나의 순간, 화려한 조명에 빛나는 설리스카이워크 모습이 어우러져 색다른 분위기를 자아내고 있어요❤ه❤ 설리스카이워크는 38m 높이에 만들어져서, 사방에 탁 트여있는 남해 를 조망할 수 있는 곳인데요. 높은 하늘에서 담은 설리스카이워크 풍광은 마치 그 현장에 있는 듯 시원한 바다가 한눈에 담기네요! 오늘 설리스카이워크 랜선여행 사진에서 화면을 뚫고 나오는 힐링 바이브와 바다내음이 느껴졌다면 자유롭게 여행을 떠날 수 있는 그 날을 기다리며 마음속 깊숙히 ✋🏻저-장🤚🏻 해 두세요! 🇰🇷 국내여행 은 대한민국구석구석 📷@flameman_mr.lee 님 *코로나19의 확산으로 사회적거리두기 가 격상되었습니다. 우리 모두 건강한 일상으로 돌아가기 위해 방역수칙을 준수해 주세요!
# 4     대구 에도 올레길 이 있다는 사실, 알고 계셨나요? 대구올레길 팔공산6코스 '단산지 가는길'의 시작점인 동구 불로동고분군 ! 여름에는 싱그러운 색으로 빛나던 곳이 가을빛으로 완연한 모습이네요´▽` 불로동 고분군은 공원처럼 산책로가 잘 조성되어 있어서. 무덤 사이를 거닐며 호젓한 분위기를 즐기기 좋은 곳인데요. 솟아오른 봉분과 저 멀리 보이는 대구 도심의 모습이 어우러진 풍경을 보고 있으면 시공을 초월한 시간 여행자가 된 느낌이 들기도 해요🚀 불로동 고분군은 그 규모도 제법 커서 비대면여행지 로 제격인 곳이랍니다. 제법 쌀쌀해진 날씨만큼이나 상쾌한 가을 공기를 가슴 가득 들이마시고 싶다면, 불로동 고분군에서 비대면산책 은 어떨까요?٩( ᐛ )و 우리 모두의 건강한 일상을 위해 사회적거리두기 수칙을 준수해 주세요! 🇰🇷 국내여행 은 대한민국구석구석 📷 트래블리더12기 최지연(M.조정해), 김유정
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# 4644                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    🌸 [오징어게임 무궁화 꽃이 피었습니다 인형 근황.jpg] ⠀ 손 한쪽 ㅠ..큐ㅠㅠㅠ ⠀ “실제 오징어 게임 촬영 때 사용했던 인형이라고 해서 더 리얼한 느낌이에요 ٩(๑❛ᴗ❛๑)۶ 현재는 제작사의 요청으로 이 인형이 다시 비공개가 되었다고 하네요 🥲” ⠀ 📍진천 마차박물관 체험마을 충북 진천군 문백면 농다리로 34 ⠀ @mxnz._.n 여행에미치다 진천 오징어게임 무궁화꽃이피었습니다
# 4645                                                                                                                                                                                                                                                                                                                                                                                                 🌼 [BTS “Young Forever” 뮤비 촬영지] ⠀ 10만 송이의 백일홍 꽃밭이 펼쳐져 있어요! 🌸🌼🌺🌻 ⠀ 본래 비행장인데, 제천시에서 코로나로 지친 시민들 힐링했으면 해서 꽃을 심었다고 하네요! ⠀ 방탄소년단 뮤직비디오 찍을때는 꽃이 없었다고 해요! ⠀ 백일홍 사이사이에 넓지도 좁지도 않은 딱 적당한 길을 만들어 놔서 사진 찍기에 최적화된 장소에요! ⠀ 저는 마침 노을이 지고 있을 때라 노을구경까지 하고 왔어요 🎶 ⠀ 저는 제천의 유명 관광지인 의림지 가는 길에 우연히 가게 된 곳이라 오래 있지 못 했는데 여기 해바라기 꽃밭의 규모도 어마어마 했어요!🥺 저 대신 해바라기랑도 인생 사진 찍어주세요 💗 ⠀ ⠀ 📍모산 비행장 🗺 네이버 지도 기준 “지진옥외대피장소 의림지동주민센터 앞(비행장)” (모산 비행장 치면 안 나옴 ❌) 🧭 충북 제천시 고암동 1249 💵 입장료 없음 🔖 근처 가볼만한 곳: 의림지 (5분 거리) ⠀ @soomniful._.life__ 여행에미치다 제천 모산비행장 BTS 백일홍 제천여행 여미_제천
# 4649                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             🚣‍♀️동굴에서 투명카약을 탈 수 있는 곳이 있다아~~?🤔 1922년부터 활옥을 채굴하던 광산이 폐광되고 놀거리,볼거리가 가득하게 관광지로 재오픈 되었대요! 넷플릭스 DP 촬영스팟도 있으니 구경해보세요 :) 여름에 가면 시원하고 넘 좋을덧,,, (겨울에 가니까 추웠어요🥶) 📍충주 활옥동굴 충청북도 충주시 목벌안길 26 ✔️매일 9:30~18:30 여미 여행에미치다 활옥동굴 충주 충주여행 여미_충주
# 4650                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             🥵 더울 땐 역시 동굴 아님? 🧊 한여름에 동굴 안에서 덜덜(?) 떨면서 투명카약 타면 을매나 재밌게요~ 📍충주 활옥동굴 충북 충주시 목벌안길 26 입장료 : 성인 1만원 (입장료+카약 패키지의 경우 1.3만원!) 🤳 여미 페이스북 그룹 앨리스님 @travelaaalice 활옥동굴 외에도 전국에 있는 멋진 동굴 댓글로 추천해주시면 모아서 다시 한 번 여름여행지 콘텐츠로 소개해드릴게요 💟 여미 충주 활옥동굴 충주여행 여미_충주
# 4651                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                🦑 [오징어 게임에 진심인 사람의 여행.jpg] 게임 참가를 원하십니까? 암호를 대시오. (ㅁㄱㅎㄲㅇㅍㅇㅅㄴㄷ) 📍단양 이끼터널 @woon_zzi 여행에미치다 단양 이끼터널 오징어게임 여미_단양
#
#           card_date card_like card_watch   _id card_month card_season  \
# 0       2020년 6월 4일      3764               46          6          여름
# 1       2021년 1월 1일      4036               19          1          겨울
# 2     2020년 12월 24일      2501               12         12          겨울
# 3     2020년 12월 10일      4229               63         12          겨울
# 4      2020년 11월 3일      5686               80         11          가을
# ...             ...       ...        ...   ...        ...         ...
# 4644   2021년 9월 29일        3만              537          9          가을
# 4645    2021년 9월 8일        1만              371          9          가을
# 4649   2022년 2월 17일      5001              457          2          겨울
# 4650   2022년 7월 12일                       1380          7          여름
# 4651   2021년 9월 26일      3.9만              651          9          가을
#
#                                                                                                                                   card_content_clean  \
# 0
# 1
# 2                                                                                                                                              예술 개성
# 3
# 4                                                                                                                                                 조정
# ...                                                                                                                                              ...
# 4644                                                             오징어 게임 무궁화 인형 근황 한쪽 실제 오징어 게임 사용 인형 리얼 느낌 현재 제작사 요청 인형 마차 박물관 체험 진천군 농다리 오징어 게임 무궁화
# 4645  뮤비 송이 백일홍 꽃밭 본래 비행장 시민 힐링 뮤직비디오 백일홍 사이사이 최적화 노을 노을 구경 유명 관광지 의림지 가게 해바라기 꽃밭 규모 대신 해바라기 비행장 지도 기준 지진 옥외 대피 의림지 주민 센터 비행장 비행장 입장료 근처 의림지 비행장 백일홍
# 4649                                                                                               동굴 투명 카약 활옥 채굴 폐광 볼거리 관광지 오픈 대요 구경 활옥 동굴 매일 활옥 동굴
# 4650                                                                              동굴 동굴 투명 카약 활옥 동굴 입장료 성인 입장료 카약 패키지 경우 그룹 활옥 동굴 전국 동굴 댓글 콘텐츠 활옥 동굴
# 4651                                                                                                        오징어 게임 진심 게임 참가 암호 시오 이끼 터널 이끼 터널 오징어 게임
#
#       content_topic
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 4644              0
# 4645              0
# 4649              0
# 4650              0
# 4651              0
#
# [1848 rows x 10 columns]

# %% [markdown]
# # 결론
# - LDA를 통해 게시글의 토픽을 분류하려 하였지만, 분류된 토픽의 단어들이 해당 게시글을 대표하지 못하는 경우가 많음
# - 지역별, 계절별로 게시글을 나눠 많이 등장하는 키워드를 추출 시도
